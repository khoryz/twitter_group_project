# %% [markdown]
# # Twitter API Scraping

# %% [markdown]
# ### Packages to load

# %%
import tweepy
import configparser
import pandas as pd
import numpy as np
import json
from twython import Twython

# %% [markdown]
# ### Other stuff to load

# %%
# nothing

# %% [markdown]
# ### Loading credentials and Twython authentication

# %%
with open("../../../config_files/credentials.json") as infile:
    credentials = json.load(infile)

twitter_client = Twython(credentials["api_key"],
                         credentials["api_secret"],
                         credentials["access_token"],
                         credentials["access_token_secret"])

# %% [markdown]
# ### Data gathering test from Twython

# %%
# trying to gather from Twython

keywords = '#iPhone14Pro'

twitter_client.search(q=keywords)
# Out:
# {'statuses': [{'created_at': 'Thu Sep 15 13:38:05 +0000 2022',
#    'id': 1570406603219963905,
#    'id_str': '1570406603219963905',
#    'text': 'This is what I’m excited about today: \n\n#iPhone14Pro On Us + Apple Business Essentials + America’s largest #5G netw… https://t.co/CqWWF3DBMp',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'iPhone14Pro', 'indices': [40, 52]},
#      {'text': '5G', 'indices': [107, 110]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/CqWWF3DBMp',
#       'expanded_url': 'https://twitter.com/i/web/status/1570406603219963905',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://www.everyonesocial.com" rel="nofollow">EveryoneSocial</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 14241940,
#     'id_str': '14241940',
#     'name': 'Mike Villalobos',
#     'screen_name': 'mivhunter26',
#     'location': 'Arlington, TX',
#     'description': 'T-Mobile',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 135,
#     'friends_count': 271,
#     'listed_count': 1,
#     'created_at': 'Fri Mar 28 06:29:59 +0000 2008',
#     'favourites_count': 12440,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 4973,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1551975430588071942/F8efelOL_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1551975430588071942/F8efelOL_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14241940/1423884331',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Sep 15 13:37:57 +0000 2022',
#    'id': 1570406570483224578,
#    'id_str': '1570406570483224578',
#    'text': 'RT @explicitgzz: COURTSIDE OUT NOW ON ALL PLATFORMS 🚏 link in bio! \n\n#upcomingartist #upcomingrapper #nycdrill #rdgtm #qgtm #nycartist #Bal…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'upcomingartist', 'indices': [69, 84]},
#      {'text': 'upcomingrapper', 'indices': [85, 100]},
#      {'text': 'nycdrill', 'indices': [101, 110]},
#      {'text': 'rdgtm', 'indices': [111, 117]},
#      {'text': 'qgtm', 'indices': [118, 123]},
#      {'text': 'nycartist', 'indices': [124, 134]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'explicitgzz',
#       'name': 'EXPLICIT',
#       'id': 1331987191732506628,
#       'id_str': '1331987191732506628',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1570405645546921984,
#     'id_str': '1570405645546921984',
#     'name': 'おさなぎかざみ',
#     'screen_name': 'osanagikazami',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 0,
#     'friends_count': 0,
#     'listed_count': 0,
#     'created_at': 'Thu Sep 15 13:34:30 +0000 2022',
#     'favourites_count': 8,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 9,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1570405935054462977/JlRkJ5qf_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1570405935054462977/JlRkJ5qf_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1570405645546921984/1663248964',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Sep 08 04:08:44 +0000 2022',
#     'id': 1567726605648150529,
#     'id_str': '1567726605648150529',
#     'text': 'COURTSIDE OUT NOW ON ALL PLATFORMS 🚏 link in bio! \n\n#upcomingartist #upcomingrapper #nycdrill #rdgtm #qgtm… https://t.co/3YDihvaoUl',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'upcomingartist', 'indices': [52, 67]},
#       {'text': 'upcomingrapper', 'indices': [68, 83]},
#       {'text': 'nycdrill', 'indices': [84, 93]},
#       {'text': 'rdgtm', 'indices': [94, 100]},
#       {'text': 'qgtm', 'indices': [101, 106]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/3YDihvaoUl',
#        'expanded_url': 'https://twitter.com/i/web/status/1567726605648150529',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [108, 131]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1331987191732506628,
#      'id_str': '1331987191732506628',
#      'name': 'EXPLICIT',
#      'screen_name': 'explicitgzz',
#      'location': 'Queens, NY',
#      'description': 'stream EXPLICIT, tap link below 🎶',
#      'url': 'https://t.co/ewVDjYeMgw',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/ewVDjYeMgw',
#          'expanded_url': 'https://withkoji.com/@explicit',
#          'display_url': 'withkoji.com/@explicit',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 9,
#      'friends_count': 2,
#      'listed_count': 0,
#      'created_at': 'Thu Nov 26 15:44:36 +0000 2020',
#      'favourites_count': 66,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 196,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1570405670528159746/t7i2-raz_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1570405670528159746/t7i2-raz_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1331987191732506628/1606414145',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 54,
#     'favorite_count': 57,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 54,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Sep 15 13:37:57 +0000 2022',
#    'id': 1570406568663085059,
#    'id_str': '1570406568663085059',
#    'text': 'RT @explicitgzz: COURTSIDE OUT NOW ON ALL PLATFORMS 🚏 link in bio! \n\n#upcomingartist #upcomingrapper #nycdrill #rdgtm #qgtm #nycartist #Bal…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'upcomingartist', 'indices': [69, 84]},
#      {'text': 'upcomingrapper', 'indices': [85, 100]},
#      {'text': 'nycdrill', 'indices': [101, 110]},
#      {'text': 'rdgtm', 'indices': [111, 117]},
#      {'text': 'qgtm', 'indices': [118, 123]},
#      {'text': 'nycartist', 'indices': [124, 134]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'explicitgzz',
#       'name': 'EXPLICIT',
#       'id': 1331987191732506628,
#       'id_str': '1331987191732506628',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1570405885297696771,
#     'id_str': '1570405885297696771',
#     'name': 'やまみはるな',
#     'screen_name': 'yamamiharuna',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 0,
#     'friends_count': 0,
#     'listed_count': 0,
#     'created_at': 'Thu Sep 15 13:35:26 +0000 2022',
#     'favourites_count': 6,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 7,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1570406033323102209/9cqgX4fE_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1570406033323102209/9cqgX4fE_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1570405885297696771/1663248987',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Sep 08 04:08:44 +0000 2022',
#     'id': 1567726605648150529,
#     'id_str': '1567726605648150529',
#     'text': 'COURTSIDE OUT NOW ON ALL PLATFORMS 🚏 link in bio! \n\n#upcomingartist #upcomingrapper #nycdrill #rdgtm #qgtm… https://t.co/3YDihvaoUl',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'upcomingartist', 'indices': [52, 67]},
#       {'text': 'upcomingrapper', 'indices': [68, 83]},
#       {'text': 'nycdrill', 'indices': [84, 93]},
#       {'text': 'rdgtm', 'indices': [94, 100]},
#       {'text': 'qgtm', 'indices': [101, 106]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/3YDihvaoUl',
#        'expanded_url': 'https://twitter.com/i/web/status/1567726605648150529',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [108, 131]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1331987191732506628,
#      'id_str': '1331987191732506628',
#      'name': 'EXPLICIT',
#      'screen_name': 'explicitgzz',
#      'location': 'Queens, NY',
#      'description': 'stream EXPLICIT, tap link below 🎶',
#      'url': 'https://t.co/ewVDjYeMgw',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/ewVDjYeMgw',
#          'expanded_url': 'https://withkoji.com/@explicit',
#          'display_url': 'withkoji.com/@explicit',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 9,
#      'friends_count': 2,
#      'listed_count': 0,
#      'created_at': 'Thu Nov 26 15:44:36 +0000 2020',
#      'favourites_count': 66,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 196,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1570405670528159746/t7i2-raz_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1570405670528159746/t7i2-raz_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1331987191732506628/1606414145',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 54,
#     'favorite_count': 57,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 54,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Sep 15 13:37:49 +0000 2022',
#    'id': 1570406536190791683,
#    'id_str': '1570406536190791683',
#    'text': 'RT @moonluvsaturday: -Pls rt-\n✨ มูก่อนเลย ถ้าวันที่16นี้ walk in เข้าไปซื้อ iPhone 14 pro สีเสปซแบล๊ค 128-256 ได้1 เครื่อง แจก 100/คน 2คน…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'moonluvsaturday',
#       'name': '\U0001faf6🏻ft.เอาไว้ฟอลกลับ',
#       'id': 1257188854215278592,
#       'id_str': '1257188854215278592',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'th', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1513138810225192962,
#     'id_str': '1513138810225192962',
#     'name': 'bibubu ♡︎ || 부부 💜',
#     'screen_name': 'bubu_cutiee',
#     'location': 'ɪɴ ʏᴏᴜʀ ʜᴇᴀʀᴛᴇᴜ ♥︎',
#     'description': '`` อยู่หลายด้อม คีพเกือบทุกวงค่ะ ติ่งไปแล้วครึ่งวงการไม่เกินจริง ไอเยิฟเคพัพ เคพัพอิสมายไลฟ์ เพราะฉะนั้นไอด๊อนแคร์บอสตันไอแคร์จัสมายไลฟ์ค่ะ! เชิ่ด!💃🏻💃🏻 ☆ ´´',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 9,
#     'friends_count': 1280,
#     'listed_count': 0,
#     'created_at': 'Sun Apr 10 12:56:27 +0000 2022',
#     'favourites_count': 754,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 3699,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1564602501080715265/kaK-AzT2_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1564602501080715265/kaK-AzT2_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1513138810225192962/1661865315',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Sep 14 17:07:16 +0000 2022',
#     'id': 1570096859376668673,
#     'id_str': '1570096859376668673',
#     'text': '-Pls rt-\n✨ มูก่อนเลย ถ้าวันที่16นี้ walk in เข้าไปซื้อ iPhone 14 pro สีเสปซแบล๊ค 128-256 ได้1 เครื่อง แจก 100/คน 2ค… https://t.co/kns7aIAF57',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/kns7aIAF57',
#        'expanded_url': 'https://twitter.com/i/web/status/1570096859376668673',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'th', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1257188854215278592,
#      'id_str': '1257188854215278592',
#      'name': '\U0001faf6🏻ft.เอาไว้ฟอลกลับ',
#      'screen_name': 'moonluvsaturday',
#      'location': '',
#      'description': 'มอป.',
#      'url': 'https://t.co/nf9Swezp8E',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/nf9Swezp8E',
#          'expanded_url': 'https://youtu.be/EFHeeRIDAsg',
#          'display_url': 'youtu.be/EFHeeRIDAsg',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 53,
#      'friends_count': 143,
#      'listed_count': 0,
#      'created_at': 'Mon May 04 06:02:46 +0000 2020',
#      'favourites_count': 16,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 52,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1551614828766445568/me60ONnT_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1551614828766445568/me60ONnT_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1257188854215278592/1658768789',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 68,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'th'},
#    'is_quote_status': False,
#    'retweet_count': 68,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'th'},
#   {'created_at': 'Thu Sep 15 13:37:25 +0000 2022',
#    'id': 1570406433367244800,
#    'id_str': '1570406433367244800',
#    'text': 'I like older women, attracted to older woman, funny young man love older women | love T-Shirt\nRedbubble:… https://t.co/8kCyD1SatQ',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/8kCyD1SatQ',
#       'expanded_url': 'https://twitter.com/i/web/status/1570406433367244800',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [106, 129]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1450420913636270082,
#     'id_str': '1450420913636270082',
#     'name': 'LaBenzArtista',
#     'screen_name': 'ElartistaKha',
#     'location': '',
#     'description': 'Hello.. This is my store https://t.co/COXK5ptLXT, explore it.',
#     'url': 'https://t.co/vI9R12pUwR',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/vI9R12pUwR',
#         'expanded_url': 'https://rdbl.co/3vs9okn',
#         'display_url': 'rdbl.co/3vs9okn',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/COXK5ptLXT',
#         'expanded_url': 'http://rdbl.co/3vs9okn',
#         'display_url': 'rdbl.co/3vs9okn',
#         'indices': [25, 48]}]}},
#     'protected': False,
#     'followers_count': 0,
#     'friends_count': 8,
#     'listed_count': 0,
#     'created_at': 'Tue Oct 19 11:18:03 +0000 2021',
#     'favourites_count': 1,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 7,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1450473692023214091/Z41EYmOg_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1450473692023214091/Z41EYmOg_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1450420913636270082/1662172692',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Sep 15 13:36:51 +0000 2022',
#    'id': 1570406293323812866,
#    'id_str': '1570406293323812866',
#    'text': 'خصائص ايفون 14 pro و pro max #iPhone14Pro #apple #AppleEvent #iPhone14ProMax https://t.co/RcpX3HPGH2',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'iPhone14Pro', 'indices': [29, 41]},
#      {'text': 'apple', 'indices': [42, 48]},
#      {'text': 'AppleEvent', 'indices': [49, 60]},
#      {'text': 'iPhone14ProMax', 'indices': [61, 76]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1570406287950725121,
#       'id_str': '1570406287950725121',
#       'indices': [77, 100],
#       'media_url': 'http://pbs.twimg.com/media/Fcs0MtJXwAEpOez.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Fcs0MtJXwAEpOez.jpg',
#       'url': 'https://t.co/RcpX3HPGH2',
#       'display_url': 'pic.twitter.com/RcpX3HPGH2',
#       'expanded_url': 'https://twitter.com/omarmujahed77/status/1570406293323812866/photo/1',
#       'type': 'photo',
#       'sizes': {'small': {'w': 679, 'h': 680, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1125, 'h': 1126, 'resize': 'fit'},
#        'medium': {'w': 1125, 'h': 1126, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1570406287950725121,
#       'id_str': '1570406287950725121',
#       'indices': [77, 100],
#       'media_url': 'http://pbs.twimg.com/media/Fcs0MtJXwAEpOez.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Fcs0MtJXwAEpOez.jpg',
#       'url': 'https://t.co/RcpX3HPGH2',
#       'display_url': 'pic.twitter.com/RcpX3HPGH2',
#       'expanded_url': 'https://twitter.com/omarmujahed77/status/1570406293323812866/photo/1',
#       'type': 'photo',
#       'sizes': {'small': {'w': 679, 'h': 680, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1125, 'h': 1126, 'resize': 'fit'},
#        'medium': {'w': 1125, 'h': 1126, 'resize': 'fit'}}},
#      {'id': 1570406287942238210,
#       'id_str': '1570406287942238210',
#       'indices': [77, 100],
#       'media_url': 'http://pbs.twimg.com/media/Fcs0MtHWQAInQmT.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Fcs0MtHWQAInQmT.jpg',
#       'url': 'https://t.co/RcpX3HPGH2',
#       'display_url': 'pic.twitter.com/RcpX3HPGH2',
#       'expanded_url': 'https://twitter.com/omarmujahed77/status/1570406293323812866/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 680, 'h': 678, 'resize': 'fit'},
#        'medium': {'w': 1125, 'h': 1122, 'resize': 'fit'},
#        'large': {'w': 1125, 'h': 1122, 'resize': 'fit'}}}]},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1512957791954251782,
#     'id_str': '1512957791954251782',
#     'name': 'Abu Ayham',
#     'screen_name': 'omarmujahed77',
#     'location': '',
#     'description': '♥️😂',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1,
#     'friends_count': 23,
#     'listed_count': 0,
#     'created_at': 'Sun Apr 10 00:57:19 +0000 2022',
#     'favourites_count': 24,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 5,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1512958005251293188/IQ92pjcA_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1512958005251293188/IQ92pjcA_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'und'},
#   {'created_at': 'Thu Sep 15 13:36:44 +0000 2022',
#    'id': 1570406261333856259,
#    'id_str': '1570406261333856259',
#    'text': 'RT @PRainbowreview: ตั้งแต่อัพเดตกูก็คือตะลึงกับอันนี้สุดละ!!\nชอบม๊ากมึง ถูกใจสายแต่งรูปแต่ขี้เกียจ\nงานนี้ก็แค่ก้อปวาง มึงก็คุมโทนไปเลยค่ะ…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'PRainbowreview',
#       'name': 'เจ้าหญิงสายรุ้ง',
#       'id': 1468234012573540367,
#       'id_str': '1468234012573540367',
#       'indices': [3, 18]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'th', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 931786628204412928,
#     'id_str': '931786628204412928',
#     'name': 'อลิซตัวน้อย ·ᴥ·',
#     'screen_name': 'miinialicia',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 6,
#     'friends_count': 84,
#     'listed_count': 0,
#     'created_at': 'Sat Nov 18 07:30:18 +0000 2017',
#     'favourites_count': 33,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 6692,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1540311687798325248/BZpY-PuC_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1540311687798325248/BZpY-PuC_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/931786628204412928/1650195253',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Sep 14 22:20:08 +0000 2022',
#     'id': 1570175594708733952,
#     'id_str': '1570175594708733952',
#     'text': 'ตั้งแต่อัพเดตกูก็คือตะลึงกับอันนี้สุดละ!!\nชอบม๊ากมึง ถูกใจสายแต่งรูปแต่ขี้เกียจ\nงานนี้ก็แค่ก้อปวาง มึงก็คุมโทนไปเลย… https://t.co/j4fz9tFtZT',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/j4fz9tFtZT',
#        'expanded_url': 'https://twitter.com/i/web/status/1570175594708733952',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'th', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1468234012573540367,
#      'id_str': '1468234012573540367',
#      'name': 'เจ้าหญิงสายรุ้ง',
#      'screen_name': 'PRainbowreview',
#      'location': '',
#      'description': '🌈💫☁️😳ใช้จริงรีวิวเอง ป้ายยาของต้องมี  ห้ามก้อปรูปไปใช้ไม่ว่ากรณีใด❌ | afflink งับ |',
#      'url': 'https://t.co/SOrfI5NFF9',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/SOrfI5NFF9',
#          'expanded_url': 'https://msha.ke/kotchapang',
#          'display_url': 'msha.ke/kotchapang',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 296,
#      'friends_count': 57,
#      'listed_count': 0,
#      'created_at': 'Tue Dec 07 15:01:26 +0000 2021',
#      'favourites_count': 15,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 514,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1568999799638360066/7XwPAiX3_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1568999799638360066/7XwPAiX3_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1468234012573540367/1638898168',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 506,
#     'favorite_count': 702,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'th'},
#    'is_quote_status': False,
#    'retweet_count': 506,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'th'},
#   {'created_at': 'Thu Sep 15 13:36:40 +0000 2022',
#    'id': 1570406247018668032,
#    'id_str': '1570406247018668032',
#    'text': 'Well, finally!  I got a ship notification. Took long enough. 🤪\n\n#Apple #iPhone #iPhone14 #iPhone14Pro… https://t.co/TFAs6PtIlY',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'Apple', 'indices': [64, 70]},
#      {'text': 'iPhone', 'indices': [71, 78]},
#      {'text': 'iPhone14', 'indices': [79, 88]},
#      {'text': 'iPhone14Pro', 'indices': [89, 101]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/TFAs6PtIlY',
#       'expanded_url': 'https://twitter.com/i/web/status/1570406247018668032',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [103, 126]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1252212242520641537,
#     'id_str': '1252212242520641537',
#     'name': 'Apple Snob 😝',
#     'screen_name': 'Moto760',
#     'location': 'Springfield MO',
#     'description': 'Love technology of all types but really love my Apple products the most. 💙🇺🇸',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1275,
#     'friends_count': 283,
#     'listed_count': 4,
#     'created_at': 'Mon Apr 20 12:27:35 +0000 2020',
#     'favourites_count': 14100,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 8385,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1568585819622883331/q3Vdwn85_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1568585819622883331/q3Vdwn85_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1252212242520641537/1662815448',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Sep 15 13:35:07 +0000 2022',
#    'id': 1570405857225224192,
#    'id_str': '1570405857225224192',
#    'text': 'My #iPhone14ProMax &amp; #iPhone14Pro have been shipped 👍🏼',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'iPhone14ProMax', 'indices': [3, 18]},
#      {'text': 'iPhone14Pro', 'indices': [25, 37]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://tapbots.com/tweetbot" rel="nofollow">Tweetbot for iΟS</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 86597362,
#     'id_str': '86597362',
#     'name': 'Eng. G-fUnK',
#     'screen_name': 'MrGfUnK',
#     'location': 'Kuwait - Miami',
#     'description': 'An Engineer by Trade & a Geek by Design #AppleFan #AppleGeek #FIUAlumni #HeatLifer #IAmHeatNation #StraightOuttaKuwait  Instagram: MrGfUnKk  Snapchat: MrGfUnKk',
#     'url': 'https://t.co/nC9uy8BxLF',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/nC9uy8BxLF',
#         'expanded_url': 'http://Reachnetwork.co/mo-alk',
#         'display_url': 'Reachnetwork.co/mo-alk',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 333,
#     'friends_count': 411,
#     'listed_count': 0,
#     'created_at': 'Sat Oct 31 20:33:37 +0000 2009',
#     'favourites_count': 147,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 22628,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F2F2F2',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1216019826008842240/FZhCTatJ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1216019826008842240/FZhCTatJ_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/86597362/1605386557',
#     'profile_link_color': '5A696E',
#     'profile_sidebar_border_color': 'E7EDF0',
#     'profile_sidebar_fill_color': 'EB8888',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Sep 15 13:34:58 +0000 2022',
#    'id': 1570405817677139970,
#    'id_str': '1570405817677139970',
#    'text': 'RT @SPIDEReGAMES: #CONCOURS !\n🎁 Tentez de gagner un IPhone 14 !\n\nPour participer : Like + RT + follow \n@SPIDEReGAMES \n@levraizarkx \n\n⏱ TAS…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'CONCOURS', 'indices': [18, 27]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SPIDEReGAMES',
#       'name': 'Spider Games',
#       'id': 1100741938184142850,
#       'id_str': '1100741938184142850',
#       'indices': [3, 16]},
#      {'screen_name': 'SPIDEReGAMES',
#       'name': 'Spider Games',
#       'id': 1100741938184142850,
#       'id_str': '1100741938184142850',
#       'indices': [103, 116]},
#      {'screen_name': 'levraizarkx',
#       'name': 'ZarKx \uea00',
#       'id': 1550562701243518977,
#       'id_str': '1550562701243518977',
#       'indices': [118, 130]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1480940388777144320,
#     'id_str': '1480940388777144320',
#     'name': 'DVM_KingA',
#     'screen_name': 'dayvi_gn',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 23,
#     'friends_count': 43,
#     'listed_count': 0,
#     'created_at': 'Tue Jan 11 16:31:34 +0000 2022',
#     'favourites_count': 226,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 191,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1562916886622486528/NaFftBG2_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1562916886622486528/NaFftBG2_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1480940388777144320/1642696733',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Sep 15 09:01:22 +0000 2022',
#     'id': 1570336966624911360,
#     'id_str': '1570336966624911360',
#     'text': '#CONCOURS !\n🎁 Tentez de gagner un IPhone 14 !\n\nPour participer : Like + RT + follow \n@SPIDEReGAMES \n@levraizarkx… https://t.co/AyPB6GfMoF',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'CONCOURS', 'indices': [0, 9]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'SPIDEReGAMES',
#        'name': 'Spider Games',
#        'id': 1100741938184142850,
#        'id_str': '1100741938184142850',
#        'indices': [85, 98]},
#       {'screen_name': 'levraizarkx',
#        'name': 'ZarKx \uea00',
#        'id': 1550562701243518977,
#        'id_str': '1550562701243518977',
#        'indices': [100, 112]}],
#      'urls': [{'url': 'https://t.co/AyPB6GfMoF',
#        'expanded_url': 'https://twitter.com/i/web/status/1570336966624911360',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [114, 137]}]},
#     'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1100741938184142850,
#      'id_str': '1100741938184142850',
#      'name': 'Spider Games',
#      'screen_name': 'SPIDEReGAMES',
#      'location': 'Sinon Go 200K ',
#      'description': '❤ les gagnants seront affichés sur mon Instagram : spiderr_gamess ❤️',
#      'url': 'https://t.co/nr3LhcimWD',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/nr3LhcimWD',
#          'expanded_url': 'https://www.youtube.com/c/SPIDERGAMESSS/featured',
#          'display_url': 'youtube.com/c/SPIDERGAMESS…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 3253,
#      'friends_count': 34,
#      'listed_count': 0,
#      'created_at': 'Wed Feb 27 12:58:23 +0000 2019',
#      'favourites_count': 453,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 301,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1569599107760590848/G-IRjFJj_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1569599107760590848/G-IRjFJj_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1100741938184142850/1663056576',
#      'profile_link_color': '981CEB',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
# ...
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 5071,
#     'favorite_count': 18136,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 5071,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Sep 15 13:32:50 +0000 2022',
#    'id': 1570405282915962881,
#    'id_str': '1570405282915962881',
#    'text': 'Робота Dynamic Island в SlowMotion.\n\nМагія 🤩\n\n#dynamicisland #iPhone14Pro https://t.co/AM49ZBy6Pe',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'dynamicisland', 'indices': [46, 60]},
#      {'text': 'iPhone14Pro', 'indices': [61, 73]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1570405251664039937,
#       'id_str': '1570405251664039937',
#       'indices': [74, 97],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1570405251664039937/pu/img/uhrsTZ6IUeUQAG9o.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1570405251664039937/pu/img/uhrsTZ6IUeUQAG9o.jpg',
#       'url': 'https://t.co/AM49ZBy6Pe',
#       'display_url': 'pic.twitter.com/AM49ZBy6Pe',
#       'expanded_url': 'https://twitter.com/mulchitach/status/1570405282915962881/video/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 555, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 315, 'resize': 'fit'},
#        'large': {'w': 1280, 'h': 592, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1570405251664039937,
#       'id_str': '1570405251664039937',
#       'indices': [74, 97],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1570405251664039937/pu/img/uhrsTZ6IUeUQAG9o.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1570405251664039937/pu/img/uhrsTZ6IUeUQAG9o.jpg',
#       'url': 'https://t.co/AM49ZBy6Pe',
#       'display_url': 'pic.twitter.com/AM49ZBy6Pe',
#       'expanded_url': 'https://twitter.com/mulchitach/status/1570405282915962881/video/1',
#       'type': 'video',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 555, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 315, 'resize': 'fit'},
#        'large': {'w': 1280, 'h': 592, 'resize': 'fit'}},
#       'video_info': {'aspect_ratio': [80, 37],
#        'duration_millis': 20500,
#        'variants': [{'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1570405251664039937/pu/vid/778x360/f5fEORyGgjGZ7a9z.mp4?tag=12'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/ext_tw_video/1570405251664039937/pu/pl/kccduOHqzdN4HA-d.m3u8?tag=12&container=fmp4'},
#         {'bitrate': 256000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1570405251664039937/pu/vid/582x270/qrFKQV-FZevSLAMu.mp4?tag=12'},
#         {'bitrate': 2176000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1570405251664039937/pu/vid/1280x592/HFnS1quQ7MrW4HJk.mp4?tag=12'}]},
#       'additional_media_info': {'monetizable': False}}]},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1567148092427849728,
#     'id_str': '1567148092427849728',
#     'name': 'Мульчитач 🇺🇦',
#     'screen_name': 'mulchitach',
#     'location': 'Украина',
#     'description': 'Стисло солов’їною про новини зі світу технологій і не тільки ⚡️',
#     'url': 'https://t.co/zHOFmw2Byu',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/zHOFmw2Byu',
#         'expanded_url': 'https://t.me/mulchitach',
#         'display_url': 't.me/mulchitach',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2,
#     'friends_count': 32,
#     'listed_count': 0,
#     'created_at': 'Tue Sep 06 13:50:17 +0000 2022',
#     'favourites_count': 46,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 44,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1567148239379365888/uuc4x8Dn_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1567148239379365888/uuc4x8Dn_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1567148092427849728/1662473619',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': True,
#    'lang': 'und'},
#   {'created_at': 'Thu Sep 15 13:32:41 +0000 2022',
#    'id': 1570405242096820227,
#    'id_str': '1570405242096820227',
#    'text': '🚀 Launcher for iOS 16 Lock Screen 🔥\n\nFull SwiftUI Source Code:\nhttps://t.co/j4meCR7cuX\n\n#iPhone14Pro #swiftui… https://t.co/iqv5UmOsFD',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'iPhone14Pro', 'indices': [88, 100]},
#      {'text': 'swiftui', 'indices': [101, 109]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/j4meCR7cuX',
#       'expanded_url': 'https://bit.ly/LockScreen-Launcher-iOS16-Apps4World',
#       'display_url': 'bit.ly/LockScreen-Lau…',
#       'indices': [63, 86]},
#      {'url': 'https://t.co/iqv5UmOsFD',
#       'expanded_url': 'https://twitter.com/i/web/status/1570405242096820227',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [111, 134]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1447204110890160134,
#     'id_str': '1447204110890160134',
#     'name': 'Apps4World',
#     'screen_name': '_Apps4World_',
#     'location': 'United States',
#     'description': 'iOS App Templates\n- Publish your first iOS app within hours\n- Full Xcode Projects\n- Swift & SwiftUI Code',
#     'url': 'https://t.co/XvzTmKobG9',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/XvzTmKobG9',
#         'expanded_url': 'https://www.apps4world.com',
#         'display_url': 'apps4world.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 16,
#     'friends_count': 0,
#     'listed_count': 0,
#     'created_at': 'Sun Oct 10 14:15:29 +0000 2021',
#     'favourites_count': 13,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 64,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1447204211104624645/HkBjIVvh_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1447204211104624645/HkBjIVvh_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1447204110890160134/1641332539',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Sep 15 13:31:49 +0000 2022',
#    'id': 1570405026119712768,
#    'id_str': '1570405026119712768',
#    'text': 'RT @munchyzmunch: 🚨🚨 New Video Alert 🚨🚨\nHow to Get iPhone14 Pro Dynamic Island on Any Android Without Root\nhttps://t.co/eNDG2x0AaS\nRTs Appr…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'munchyzmunch',
#       'name': 'Munchy',
#       'id': 1307247004972654593,
#       'id_str': '1307247004972654593',
#       'indices': [3, 16]}],
#     'urls': [{'url': 'https://t.co/eNDG2x0AaS',
#       'expanded_url': 'https://youtu.be/w4QkUeyayVM',
#       'display_url': 'youtu.be/w4QkUeyayVM',
#       'indices': [107, 130]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 436200762,
#     'id_str': '436200762',
#     'name': 'manOS(3,3)(🦦,\xa0🦦)',
#     'screen_name': 'emmpetr',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 25,
#     'friends_count': 279,
#     'listed_count': 1,
#     'created_at': 'Tue Dec 13 22:27:01 +0000 2011',
#     'favourites_count': 1742,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2627,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'DBE9ED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme17/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme17/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1564145383051329537/fnKmlYd4_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1564145383051329537/fnKmlYd4_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/436200762/1571289181',
#     'profile_link_color': 'CC3366',
#     'profile_sidebar_border_color': 'DBE9ED',
#     'profile_sidebar_fill_color': 'E6F6F9',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Sep 15 10:22:47 +0000 2022',
#     'id': 1570357452150816768,
#     'id_str': '1570357452150816768',
#     'text': '🚨🚨 New Video Alert 🚨🚨\nHow to Get iPhone14 Pro Dynamic Island on Any Android Without Root\nhttps://t.co/eNDG2x0AaS\nRT… https://t.co/0uzykyBPfy',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/eNDG2x0AaS',
#        'expanded_url': 'https://youtu.be/w4QkUeyayVM',
#        'display_url': 'youtu.be/w4QkUeyayVM',
#        'indices': [89, 112]},
#       {'url': 'https://t.co/0uzykyBPfy',
#        'expanded_url': 'https://twitter.com/i/web/status/1570357452150816768',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1307247004972654593,
#      'id_str': '1307247004972654593',
#      'name': 'Munchy',
#      'screen_name': 'munchyzmunch',
#      'location': '',
#      'description': '',
#      'url': 'https://t.co/KVtg7DvM5r',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KVtg7DvM5r',
#          'expanded_url': 'https://www.youtube.com/munchy_cool',
#          'display_url': 'youtube.com/munchy_cool',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1157,
#      'friends_count': 246,
#      'listed_count': 1,
#      'created_at': 'Sat Sep 19 09:16:03 +0000 2020',
#      'favourites_count': 32,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 2751,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1480662481165037570/TZxIiigH_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1480662481165037570/TZxIiigH_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1307247004972654593/1641851985',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.112,
#   'max_id': 1570406603219963905,
#   'max_id_str': '1570406603219963905',
#   'next_results': '?max_id=1570405026119712767&q=%23iPhone14Pro&include_entities=1',
#   'query': '%23iPhone14Pro',
#   'refresh_url': '?since_id=1570406603219963905&q=%23iPhone14Pro&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %% [markdown]
# ### Loading credentials and Tweepy authentication

# %%
# read configs

config = configparser.ConfigParser()
config.read('../../../config_files/config.ini')

api_key = config['twitter']['api_key']
api_key_secret = config['twitter']['api_key_secret']

access_token = config['twitter']['access_token']
access_token_secret = config['twitter']['access_token_secret']

# %%
# authentication

auth = tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %% [markdown]
# ### Data gathering from Twitter API

# %% [markdown]
# #### Option 1

# %%
# search by user

# user = 'veritasium'
# limit=300
# tweets = tweepy.Cursor(api.user_timeline, screen_name=user, count=200, tweet_mode='extended').items(limit)

# search by keyword or hashtag (works too for @user)
keywords = "#iPhone14Pro -filter:retweets"
limit = 1000
tweets = tweepy.Cursor(
    api.search_tweets, q=keywords, count=100, lang="en", tweet_mode="extended").items(limit)

# create DataFrame
columns = [
    "User",
    "Tweet_time",
    "Tweet",
    "Hashtag",
    "Retweet",
    "Favorite",
    "Join_time",
    "Follower",
    "Friend",
]

data = []

for tweet in tweets:
    data.append(
        [
            tweet.user.screen_name,
            tweet.created_at,
            tweet.full_text,
            tweet.entities["hashtags"],
            tweet.retweet_count,
            tweet.favorite_count,
            tweet.user.created_at,
            tweet.user.followers_count,
            tweet.user.friends_count,
        ]
    )

df = pd.DataFrame(data, columns=columns)

df.head()
# Out:
#            User                Tweet_time  \
# 0   mivhunter26 2022-09-15 13:38:05+00:00
# 1  ElartistaKha 2022-09-15 13:37:25+00:00
# 2       Moto760 2022-09-15 13:36:40+00:00
# 3       MrGfUnK 2022-09-15 13:35:07+00:00
# 4  _Apps4World_ 2022-09-15 13:32:41+00:00
#
#                                                Tweet  \
# 0  This is what I’m excited about today: \n\n#iPh...
# 1  I like older women, attracted to older woman, ...
# 2  Well, finally!  I got a ship notification. Too...
# 3  My #iPhone14ProMax &amp; #iPhone14Pro have bee...
# 4  🚀 Launcher for iOS 16 Lock Screen 🔥\n\nFull Sw...
#
#                                              Hashtag  Retweet  Favorite  \
# 0  [{'text': 'iPhone14Pro', 'indices': [40, 52]},...        0         0
# 1  [{'text': 'shirt', 'indices': [164, 170]}, {'t...        0         0
# 2  [{'text': 'Apple', 'indices': [64, 70]}, {'tex...        0         0
# 3  [{'text': 'iPhone14ProMax', 'indices': [3, 18]...        0         0
# 4  [{'text': 'iPhone14Pro', 'indices': [88, 100]}...        0         0
#
#                   Join_time  Follower  Friend
# 0 2008-03-28 06:29:59+00:00       135     271
# 1 2021-10-19 11:18:03+00:00         0       8
# 2 2020-04-20 12:27:35+00:00      1275     283
# 3 2009-10-31 20:33:37+00:00       333     411
# 4 2021-10-10 14:15:29+00:00        16       0

# %% [markdown]
# #### Option 2

# %%
# gathering data from API

keywords = '#iPhone14Pro'
limit = 1000

tweets = tweepy.Cursor(api.search_tweets, q=keywords, lang='en', count=100,
                       tweet_mode='extended').items(limit)

# creating DataFrame

columns = ['User', 'DateTime', 'Tweet']
data = []

for tweet in tweets:
    data.append([tweet.user.screen_name, tweet.created_at, tweet.full_text])
    
df = pd.DataFrame(data, columns=columns)

df.head()
# Out:
#             User                  DateTime  \
# 0    mivhunter26 2022-09-15 13:38:05+00:00
# 1  osanagikazami 2022-09-15 13:37:57+00:00
# 2   yamamiharuna 2022-09-15 13:37:57+00:00
# 3   ElartistaKha 2022-09-15 13:37:25+00:00
# 4        Moto760 2022-09-15 13:36:40+00:00
#
#                                                Tweet
# 0  This is what I’m excited about today: \n\n#iPh...
# 1  RT @explicitgzz: COURTSIDE OUT NOW ON ALL PLAT...
# 2  RT @explicitgzz: COURTSIDE OUT NOW ON ALL PLAT...
# 3  I like older women, attracted to older woman, ...
# 4  Well, finally!  I got a ship notification. Too...

# %% [markdown]
# ### Reading DataFrame for iPhone 14 Pro

# %%
#df.to_csv('../data/raw/iPhone14Prox10k_RAW_2.csv)

# %%
df14pro = pd.read_csv('../data/raw/iPhone14Prox10k_RAW.csv')
df14pro.head()
# Out:
#    Unnamed: 0             User                   DateTime  \
# 0           0         1202tung  2022-09-14 14:48:27+00:00
# 1           1  Rushike74038427  2022-09-14 14:48:05+00:00
# 2           2          papsobu  2022-09-14 14:47:40+00:00
# 3           3    _kayrozenlang  2022-09-14 14:47:27+00:00
# 4           4     SarenDebnath  2022-09-14 14:46:41+00:00
#
#                                                Tweet
# 0  RT @insanetweet: iPhone 8 while upgrading to i...
# 1  I want this case @Mrwhosetheboss \n#iphone14pr...
# 2  RT @insanetweet: iPhone 8 while upgrading to i...
# 3  RT @btslabs_global: 🏆Win iPhone14 Pro\n\nWith ...
# 4  RT @btslabs_global: 🏆Win iPhone14 Pro\n\nWith ...

# %%
df14pro['User'].value_counts()
# Out:
# thebbmafrica       63
# ChronicallyTG      41
# FaizanA17120449    40
# XXFemale1          39
# sgmobmart          34
#                    ..
# p_929303            1
# bonxcviii           1
# twtfnov             1
# axososad            1
# Getpaidrealquic     1
# Name: User, Length: 8703, dtype: int64

# %% [markdown]
# ### Cleaning Tweet Column

# %%
df14pro['Tweet'][0]
# Out:
# 'RT @insanetweet: iPhone 8 while upgrading to iOS 16\n\n#iOS16 #iPhone14 #iPhone14Pro \n https://t.co/IOpAaBnHus'

# %%
"""import re
import string

text = df14pro['Tweet'][0]
remove = string.punctuation
remove = remove.replace('#', '')
pattern = r"[{}]".format(remove)

re.sub(pattern, '', text)"""
# Out:
# 'import re\nimport string\n\ntext = df14pro[\'Tweet\'][0]\nremove = string.punctuation\nremove = remove.replace(\'#\', \'\')\npattern = r"[{}]".format(remove)\n\nre.sub(pattern, \'\', text)'

# %%
# removing punctuations and lowercase normalization
import string
text = df14pro['Tweet'][0]
text_clean1 = ''.join([i.lower() for i in text if i not in string.punctuation])
text_clean1
# Out:
# 'rt insanetweet iphone 8 while upgrading to ios 16\n\nios16 iphone14 iphone14pro \n httpstcoiopaabnhus'

# %%
# removing \n
import re
text_clean2 = re.sub('\n', ' ' , text_clean1)
text_clean2
# Out:
# 'rt insanetweet iphone 8 while upgrading to ios 16  ios16 iphone14 iphone14pro   httpstcoiopaabnhus'

# %%
# removing url
text_clean3 = result = re.sub(r'http\S+', '', text_clean2)
text_clean3
# Out:
# 'rt insanetweet iphone 8 while upgrading to ios 16  ios16 iphone14 iphone14pro   '

# %%
# importing stopwords
import nltk
from nltk.corpus import stopwords
cachedStopWords = stopwords.words('english')
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# removing stopwords
text_clean4 = ' '.join([word for word in text_clean3.split() if word not in stopwords.words('english')])
print(text)
# Out:
# RT @insanetweet: iPhone 8 while upgrading to iOS 16
#
# #iOS16 #iPhone14 #iPhone14Pro
#  https://t.co/IOpAaBnHus

# %%
# counting single words within a string
def word_count(str):
    counts = dict()
    words = str.split()
    
    for word in words:
        if word in counts:
            counts[word] += 1
        else:
            counts[word] = 1
    return counts

print(word_count(text_clean4))
# Out:
# {'rt': 1, 'insanetweet': 1, 'iphone': 1, '8': 1, 'upgrading': 1, 'ios': 1, '16': 1, 'ios16': 1, 'iphone14': 1, 'iphone14pro': 1}

# %% [markdown]
# ### Creating boolean for retweets

# %%
df14pro.head()
# Out:
#    Unnamed: 0             User                   DateTime  \
# 0           0         1202tung  2022-09-14 14:48:27+00:00
# 1           1  Rushike74038427  2022-09-14 14:48:05+00:00
# 2           2          papsobu  2022-09-14 14:47:40+00:00
# 3           3    _kayrozenlang  2022-09-14 14:47:27+00:00
# 4           4     SarenDebnath  2022-09-14 14:46:41+00:00
#
#                                                Tweet
# 0  RT @insanetweet: iPhone 8 while upgrading to i...
# 1  I want this case @Mrwhosetheboss \n#iphone14pr...
# 2  RT @insanetweet: iPhone 8 while upgrading to i...
# 3  RT @btslabs_global: 🏆Win iPhone14 Pro\n\nWith ...
# 4  RT @btslabs_global: 🏆Win iPhone14 Pro\n\nWith ...

# %%
df14pro['Retweet'] = df14pro['Tweet'].str.contains('RT @')
df14pro
# Out:
#       Unnamed: 0             User                   DateTime  \
# 0              0         1202tung  2022-09-14 14:48:27+00:00
# 1              1  Rushike74038427  2022-09-14 14:48:05+00:00
# 2              2          papsobu  2022-09-14 14:47:40+00:00
# 3              3    _kayrozenlang  2022-09-14 14:47:27+00:00
# 4              4     SarenDebnath  2022-09-14 14:46:41+00:00
# ...          ...              ...                        ...
# 9995        9995      techonthego  2022-09-10 08:54:17+00:00
# 9996        9996        PappannaG  2022-09-10 08:52:39+00:00
# 9997        9997      dynamo_mano  2022-09-10 08:52:24+00:00
# 9998        9998      spotter81au  2022-09-10 08:52:07+00:00
# 9999        9999  Getpaidrealquic  2022-09-10 08:51:15+00:00
#
#                                                   Tweet  Retweet
# 0     RT @insanetweet: iPhone 8 while upgrading to i...     True
# 1     I want this case @Mrwhosetheboss \n#iphone14pr...    False
# 2     RT @insanetweet: iPhone 8 while upgrading to i...     True
# 3     RT @btslabs_global: 🏆Win iPhone14 Pro\n\nWith ...     True
# 4     RT @btslabs_global: 🏆Win iPhone14 Pro\n\nWith ...     True
# ...                                                 ...      ...
# 9995  Pre-order the amazing new iPhone 14 Pro on the...    False
# 9996  RT @Drife_official: iPhone users, assemble?! 😅...     True
# 9997  RT @Jazzy4Tech_: Yesterday, I went to Croma re...     True
# 9998  Perfect! #iPhone14pro #dynamicisland https://t...    False
# 9999  RT @BIGWIZZY25: Na your boyfriend wey dey sell...     True
#
# [10000 rows x 5 columns]

# %%
df14pro['Retweet'].value_counts()
# Out:
# True     7967
# False    2033
# Name: Retweet, dtype: int64

# %%
df14pro['Tweet'][1]
# Out:
# 'I want this case @Mrwhosetheboss \n#iphone14pro #iphone14procase #iphone14ProMax https://t.co/vkJB0EICT1'

# %%
df14pro['Retweet'][1]
# Out:
# False

# %%
df14pro['Tweet'] = df14pro['Tweet'].str.lower()
df14pro
# Out:
#       Unnamed: 0             User                   DateTime  \
# 0              0         1202tung  2022-09-14 14:48:27+00:00
# 1              1  Rushike74038427  2022-09-14 14:48:05+00:00
# 2              2          papsobu  2022-09-14 14:47:40+00:00
# 3              3    _kayrozenlang  2022-09-14 14:47:27+00:00
# 4              4     SarenDebnath  2022-09-14 14:46:41+00:00
# ...          ...              ...                        ...
# 9995        9995      techonthego  2022-09-10 08:54:17+00:00
# 9996        9996        PappannaG  2022-09-10 08:52:39+00:00
# 9997        9997      dynamo_mano  2022-09-10 08:52:24+00:00
# 9998        9998      spotter81au  2022-09-10 08:52:07+00:00
# 9999        9999  Getpaidrealquic  2022-09-10 08:51:15+00:00
#
#                                                   Tweet  Retweet
# 0     rt @insanetweet: iphone 8 while upgrading to i...     True
# 1     i want this case @mrwhosetheboss \n#iphone14pr...    False
# 2     rt @insanetweet: iphone 8 while upgrading to i...     True
# 3     rt @btslabs_global: 🏆win iphone14 pro\n\nwith ...     True
# 4     rt @btslabs_global: 🏆win iphone14 pro\n\nwith ...     True
# ...                                                 ...      ...
# 9995  pre-order the amazing new iphone 14 pro on the...    False
# 9996  rt @drife_official: iphone users, assemble?! 😅...     True
# 9997  rt @jazzy4tech_: yesterday, i went to croma re...     True
# 9998  perfect! #iphone14pro #dynamicisland https://t...    False
# 9999  rt @bigwizzy25: na your boyfriend wey dey sell...     True
#
# [10000 rows x 5 columns]

# %%
#from functools import reduce
#filters = [("#iphone14", False), ("#iphone14pro", True)]
#df14pro['#iphone14'] = reduce(lambda df14pro, f: df14pro[df14pro.str.contains(f[0]) == f[1]], filters, df14pro)

# %%
#df14pro['#iphone14'] = df14pro[(df14pro['#iphone14'].str.contains('#iphone14')) & (~df14pro['#iphone14'].str.contains('upgrading'))]

# %%
#df14pro['#iphone14'] = df14pro[(df14pro.str.contains('#iphone14') == True) and (df14pro.str.contains('#iphone14pro') == False)]
#df14pro

# %%
#df14pro['#iphone14'] = np.where(df14pro['Tweet'].eq('iphone14'), 'true', 'false')
#df14pro

# %%
#df14pro['#iphone14'].value_counts()

# %%
df14pro['#iphone14'] = df14pro['Tweet'].apply(lambda x: '#iphone14' in x and 'iphone14pro' not in x)
df14pro
# Out:
#       Unnamed: 0             User                   DateTime  \
# 0              0         1202tung  2022-09-14 14:48:27+00:00
# 1              1  Rushike74038427  2022-09-14 14:48:05+00:00
# 2              2          papsobu  2022-09-14 14:47:40+00:00
# 3              3    _kayrozenlang  2022-09-14 14:47:27+00:00
# 4              4     SarenDebnath  2022-09-14 14:46:41+00:00
# ...          ...              ...                        ...
# 9995        9995      techonthego  2022-09-10 08:54:17+00:00
# 9996        9996        PappannaG  2022-09-10 08:52:39+00:00
# 9997        9997      dynamo_mano  2022-09-10 08:52:24+00:00
# 9998        9998      spotter81au  2022-09-10 08:52:07+00:00
# 9999        9999  Getpaidrealquic  2022-09-10 08:51:15+00:00
#
#                                                   Tweet  Retweet  #iphone14
# 0     rt @insanetweet: iphone 8 while upgrading to i...     True      False
# 1     i want this case @mrwhosetheboss \n#iphone14pr...    False      False
# 2     rt @insanetweet: iphone 8 while upgrading to i...     True      False
# 3     rt @btslabs_global: 🏆win iphone14 pro\n\nwith ...     True      False
# 4     rt @btslabs_global: 🏆win iphone14 pro\n\nwith ...     True      False
# ...                                                 ...      ...        ...
# 9995  pre-order the amazing new iphone 14 pro on the...    False      False
# 9996  rt @drife_official: iphone users, assemble?! 😅...     True      False
# 9997  rt @jazzy4tech_: yesterday, i went to croma re...     True      False
# 9998  perfect! #iphone14pro #dynamicisland https://t...    False      False
# 9999  rt @bigwizzy25: na your boyfriend wey dey sell...     True      False
#
# [10000 rows x 6 columns]

# %%
df14pro['#iphone14'].value_counts()
# Out:
# False    9879
# True      121
# Name: #iphone14, dtype: int64

# %%
df14pro['#iphone14pro'] = df14pro['Tweet'].str.contains('#iphone14pro')
df14pro
# Out:
#       Unnamed: 0             User                   DateTime  \
# 0              0         1202tung  2022-09-14 14:48:27+00:00
# 1              1  Rushike74038427  2022-09-14 14:48:05+00:00
# 2              2          papsobu  2022-09-14 14:47:40+00:00
# 3              3    _kayrozenlang  2022-09-14 14:47:27+00:00
# 4              4     SarenDebnath  2022-09-14 14:46:41+00:00
# ...          ...              ...                        ...
# 9995        9995      techonthego  2022-09-10 08:54:17+00:00
# 9996        9996        PappannaG  2022-09-10 08:52:39+00:00
# 9997        9997      dynamo_mano  2022-09-10 08:52:24+00:00
# 9998        9998      spotter81au  2022-09-10 08:52:07+00:00
# 9999        9999  Getpaidrealquic  2022-09-10 08:51:15+00:00
#
#                                                   Tweet  Retweet  #iphone14  \
# 0     rt @insanetweet: iphone 8 while upgrading to i...     True      False
# 1     i want this case @mrwhosetheboss \n#iphone14pr...    False      False
# 2     rt @insanetweet: iphone 8 while upgrading to i...     True      False
# 3     rt @btslabs_global: 🏆win iphone14 pro\n\nwith ...     True      False
# 4     rt @btslabs_global: 🏆win iphone14 pro\n\nwith ...     True      False
# ...                                                 ...      ...        ...
# 9995  pre-order the amazing new iphone 14 pro on the...    False      False
# 9996  rt @drife_official: iphone users, assemble?! 😅...     True      False
# 9997  rt @jazzy4tech_: yesterday, i went to croma re...     True      False
# 9998  perfect! #iphone14pro #dynamicisland https://t...    False      False
# 9999  rt @bigwizzy25: na your boyfriend wey dey sell...     True      False
#
#       #iphone14pro
# 0             True
# 1             True
# 2             True
# 3             True
# 4             True
# ...            ...
# 9995          True
# 9996          True
# 9997          True
# 9998          True
# 9999          True
#
# [10000 rows x 7 columns]

# %%
df14pro['#iphone14pro'].value_counts()
# Out:
# True     8103
# False    1897
# Name: #iphone14pro, dtype: int64

# %% [markdown]
# ### Overlap between sets

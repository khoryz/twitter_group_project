# %% [markdown]
# # Twitter API Scraping

# %% [markdown]
# ### Packages to load

# %%
import tweepy
import configparser
import pandas as pd
import numpy as np
import json
from twython import Twython

# %% [markdown]
# ### Other stuff to load

# %%
# nothing

# %% [markdown]
# ### Loading credentials and Twython authentication

# %%
with open("../../../config_files/credentials.json") as infile:
    credentials = json.load(infile)

twitter_client = Twython(credentials["api_key"],
                         credentials["api_secret"],
                         credentials["access_token"],
                         credentials["access_token_secret"])

# %% [markdown]
# ### Data gathering test from Twython

# %%
# trying to gather from Twython

keywords = '#iPhone14Pro'

twitter_client.search(q=keywords)
# Out:
# {'statuses': [{'created_at': 'Thu Sep 15 14:57:52 +0000 2022',
#    'id': 1570426680224935937,
#    'id_str': '1570426680224935937',
#    'text': 'RT @SPIDEReGAMES: #CONCOURS \n🎁 Tentez de gagner un IPhone 14 Pro !\n\nPour participer : Like + RT + follow \n@SPIDEReGAMES \n@levraizarkx &amp; @Ma…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'CONCOURS', 'indices': [18, 27]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SPIDEReGAMES',
#       'name': 'Spider Games',
#       'id': 1100741938184142850,
#       'id_str': '1100741938184142850',
#       'indices': [3, 16]},
#      {'screen_name': 'SPIDEReGAMES',
#       'name': 'Spider Games',
#       'id': 1100741938184142850,
#       'id_str': '1100741938184142850',
#       'indices': [106, 119]},
#      {'screen_name': 'levraizarkx',
#       'name': 'ZarKx \uea00',
#       'id': 1550562701243518977,
#       'id_str': '1550562701243518977',
#       'indices': [121, 133]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1518173333833068545,
#     'id_str': '1518173333833068545',
#     'name': 'FLORENT MUNIER',
#     'screen_name': 'FMunier2022',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 56,
#     'friends_count': 166,
#     'listed_count': 0,
#     'created_at': 'Sun Apr 24 10:22:28 +0000 2022',
#     'favourites_count': 413,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 115,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1518173521062600704/ZdrkdCVz_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1518173521062600704/ZdrkdCVz_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Sep 15 13:50:58 +0000 2022',
#     'id': 1570409845370626050,
#     'id_str': '1570409845370626050',
#     'text': '#CONCOURS \n🎁 Tentez de gagner un IPhone 14 Pro !\n\nPour participer : Like + RT + follow \n@SPIDEReGAMES \n@levraizarkx… https://t.co/Zopp3JKABu',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'CONCOURS', 'indices': [0, 9]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'SPIDEReGAMES',
#        'name': 'Spider Games',
#        'id': 1100741938184142850,
#        'id_str': '1100741938184142850',
#        'indices': [88, 101]},
#       {'screen_name': 'levraizarkx',
#        'name': 'ZarKx \uea00',
#        'id': 1550562701243518977,
#        'id_str': '1550562701243518977',
#        'indices': [103, 115]}],
#      'urls': [{'url': 'https://t.co/Zopp3JKABu',
#        'expanded_url': 'https://twitter.com/i/web/status/1570409845370626050',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1100741938184142850,
#      'id_str': '1100741938184142850',
#      'name': 'Spider Games',
#      'screen_name': 'SPIDEReGAMES',
#      'location': 'Sinon Go 200K ',
#      'description': '❤ les gagnants seront affichés sur mon Instagram : spiderr_gamess ❤️',
#      'url': 'https://t.co/nr3LhcimWD',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/nr3LhcimWD',
#          'expanded_url': 'https://www.youtube.com/c/SPIDERGAMESSS/featured',
#          'display_url': 'youtube.com/c/SPIDERGAMESS…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 3277,
#      'friends_count': 29,
#      'listed_count': 0,
#      'created_at': 'Wed Feb 27 12:58:23 +0000 2019',
#      'favourites_count': 455,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 302,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1569599107760590848/G-IRjFJj_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1569599107760590848/G-IRjFJj_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1100741938184142850/1663056576',
#      'profile_link_color': '981CEB',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 18,
#     'favorite_count': 18,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'fr'},
#    'is_quote_status': False,
#    'retweet_count': 18,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'fr'},
#   {'created_at': 'Thu Sep 15 14:56:53 +0000 2022',
#    'id': 1570426435273379841,
#    'id_str': '1570426435273379841',
#    'text': "Reviewing @Apple's new #dynamicisland - Dynamic island refers to the new UI that surrounds the #notch of the new… https://t.co/c0Dflvb8gp",
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'dynamicisland', 'indices': [23, 37]},
#      {'text': 'notch', 'indices': [95, 101]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Apple',
#       'name': 'Apple',
#       'id': 380749300,
#       'id_str': '380749300',
#       'indices': [10, 16]}],
#     'urls': [{'url': 'https://t.co/c0Dflvb8gp',
#       'expanded_url': 'https://twitter.com/i/web/status/1570426435273379841',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [114, 137]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1565740600447492096,
#     'id_str': '1565740600447492096',
#     'name': 'Finny Jose',
#     'screen_name': 'thegreatfinny',
#     'location': 'Pune, India',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3,
#     'friends_count': 56,
#     'listed_count': 0,
#     'created_at': 'Fri Sep 02 16:37:20 +0000 2022',
#     'favourites_count': 1,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 5,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1565743703817195521/_dRILunH_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1565743703817195521/_dRILunH_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1565740600447492096/1662137277',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Sep 15 14:56:25 +0000 2022',
#    'id': 1570426317560217602,
#    'id_str': '1570426317560217602',
#    'text': 'RT @HistoryofiPhone: The #iPhone14Pro looks amazing. \n\nDo you agree? 🤔 https://t.co/jdmtiRjQF2',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'iPhone14Pro', 'indices': [25, 37]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'HistoryofiPhone',
#       'name': 'History of the iPhone',
#       'id': 1491562481277353986,
#       'id_str': '1491562481277353986',
#       'indices': [3, 19]}],
#     'urls': [],
#     'media': [{'id': 1570269619625000960,
#       'id_str': '1570269619625000960',
#       'indices': [71, 94],
#       'media_url': 'http://pbs.twimg.com/media/Fcq35j9WAAAH67t.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Fcq35j9WAAAH67t.jpg',
#       'url': 'https://t.co/jdmtiRjQF2',
#       'display_url': 'pic.twitter.com/jdmtiRjQF2',
#       'expanded_url': 'https://twitter.com/HistoryofiPhone/status/1570269621630173184/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1600, 'h': 900, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 383, 'resize': 'fit'}},
#       'source_status_id': 1570269621630173184,
#       'source_status_id_str': '1570269621630173184',
#       'source_user_id': 1491562481277353986,
#       'source_user_id_str': '1491562481277353986'}]},
#    'extended_entities': {'media': [{'id': 1570269619625000960,
#       'id_str': '1570269619625000960',
#       'indices': [71, 94],
#       'media_url': 'http://pbs.twimg.com/media/Fcq35j9WAAAH67t.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Fcq35j9WAAAH67t.jpg',
#       'url': 'https://t.co/jdmtiRjQF2',
#       'display_url': 'pic.twitter.com/jdmtiRjQF2',
#       'expanded_url': 'https://twitter.com/HistoryofiPhone/status/1570269621630173184/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1600, 'h': 900, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 383, 'resize': 'fit'}},
#       'source_status_id': 1570269621630173184,
#       'source_status_id_str': '1570269621630173184',
#       'source_user_id': 1491562481277353986,
#       'source_user_id_str': '1491562481277353986'}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1446030758636924929,
#     'id_str': '1446030758636924929',
#     'name': 'Stefanus',
#     'screen_name': 'Stefanu369',
#     'location': '',
#     'description': 'On a mission to solve ageing.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 26,
#     'friends_count': 464,
#     'listed_count': 6,
#     'created_at': 'Thu Oct 07 08:33:14 +0000 2021',
#     'favourites_count': 4884,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1436,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1492010202186592270/LYkzJsAy_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1492010202186592270/LYkzJsAy_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1446030758636924929/1644558523',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Sep 15 04:33:46 +0000 2022',
#     'id': 1570269621630173184,
#     'id_str': '1570269621630173184',
#     'text': 'The #iPhone14Pro looks amazing. \n\nDo you agree? 🤔 https://t.co/jdmtiRjQF2',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'iPhone14Pro', 'indices': [4, 16]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1570269619625000960,
#        'id_str': '1570269619625000960',
#        'indices': [50, 73],
#        'media_url': 'http://pbs.twimg.com/media/Fcq35j9WAAAH67t.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/Fcq35j9WAAAH67t.jpg',
#        'url': 'https://t.co/jdmtiRjQF2',
#        'display_url': 'pic.twitter.com/jdmtiRjQF2',
#        'expanded_url': 'https://twitter.com/HistoryofiPhone/status/1570269621630173184/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 1600, 'h': 900, 'resize': 'fit'},
#         'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 383, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1570269619625000960,
#        'id_str': '1570269619625000960',
#        'indices': [50, 73],
#        'media_url': 'http://pbs.twimg.com/media/Fcq35j9WAAAH67t.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/Fcq35j9WAAAH67t.jpg',
#        'url': 'https://t.co/jdmtiRjQF2',
#        'display_url': 'pic.twitter.com/jdmtiRjQF2',
#        'expanded_url': 'https://twitter.com/HistoryofiPhone/status/1570269621630173184/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 1600, 'h': 900, 'resize': 'fit'},
#         'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 383, 'resize': 'fit'}}}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1491562481277353986,
#      'id_str': '1491562481277353986',
#      'name': 'History of the iPhone',
#      'screen_name': 'HistoryofiPhone',
#      'location': '',
#      'description': '📱 Daily posts of iPhone, Apple, iTunes History 📱',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 11,
#      'friends_count': 13,
#      'listed_count': 0,
#      'created_at': 'Wed Feb 09 23:59:50 +0000 2022',
#      'favourites_count': 57,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 13,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1569531714636062723/6jnb7dJ0_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1569531714636062723/6jnb7dJ0_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1491562481277353986/1663219188',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 20,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Sep 15 14:54:41 +0000 2022',
#    'id': 1570425879721025544,
#    'id_str': '1570425879721025544',
#    'text': 'Get ready to experience the power of a new iPhone 14 Pro. Pricing starting at ₹104,900* at Unicorn Store, Apple Pre… https://t.co/WqNt3Y2kjR',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/WqNt3Y2kjR',
#       'expanded_url': 'https://twitter.com/i/web/status/1570425879721025544',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1542956762,
#     'id_str': '1542956762',
#     'name': 'UnicornInfosolutions',
#     'screen_name': 'UnicornAPR',
#     'location': 'India',
#     'description': 'Premium Apple Reseller with 33 stores all over India, giving you the Ultimate Apple Experience.',
#     'url': 'https://t.co/hDrwfITdTw',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/hDrwfITdTw',
#         'expanded_url': 'https://www.shop.unicornstore.in/',
#         'display_url': 'shop.unicornstore.in',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1082,
#     'friends_count': 364,
#     'listed_count': 2,
#     'created_at': 'Mon Jun 24 10:04:38 +0000 2013',
#     'favourites_count': 44,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 3045,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1322038682203934720/OuXpCbP__normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1322038682203934720/OuXpCbP__normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1542956762/1662975461',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Sep 15 14:53:43 +0000 2022',
#    'id': 1570425636329750528,
#    'id_str': '1570425636329750528',
#    'text': 'RT @AR72014: #Apple #iPhone #iPhone14Pro #iPhone14ProMax \n\nThis is the new iPhone 14 Pro Ultra \n\n😬 https://t.co/VYX9OA4A3X',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Apple', 'indices': [13, 19]},
#      {'text': 'iPhone', 'indices': [20, 27]},
#      {'text': 'iPhone14Pro', 'indices': [28, 40]},
#      {'text': 'iPhone14ProMax', 'indices': [41, 56]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'AR72014',
#       'name': 'AR7',
#       'id': 149669367,
#       'id_str': '149669367',
#       'indices': [3, 11]}],
#     'urls': [],
#     'media': [{'id': 1570423380519669761,
#       'id_str': '1570423380519669761',
#       'indices': [99, 122],
#       'media_url': 'http://pbs.twimg.com/media/FctDvn7X0AE6LJU.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/FctDvn7X0AE6LJU.jpg',
#       'url': 'https://t.co/VYX9OA4A3X',
#       'display_url': 'pic.twitter.com/VYX9OA4A3X',
#       'expanded_url': 'https://twitter.com/AR72014/status/1570423391223484416/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 2048, 'h': 2048, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 680, 'resize': 'fit'}},
#       'source_status_id': 1570423391223484416,
#       'source_status_id_str': '1570423391223484416',
#       'source_user_id': 149669367,
#       'source_user_id_str': '149669367'}]},
#    'extended_entities': {'media': [{'id': 1570423380519669761,
#       'id_str': '1570423380519669761',
#       'indices': [99, 122],
#       'media_url': 'http://pbs.twimg.com/media/FctDvn7X0AE6LJU.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/FctDvn7X0AE6LJU.jpg',
#       'url': 'https://t.co/VYX9OA4A3X',
#       'display_url': 'pic.twitter.com/VYX9OA4A3X',
#       'expanded_url': 'https://twitter.com/AR72014/status/1570423391223484416/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 2048, 'h': 2048, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 680, 'resize': 'fit'}},
#       'source_status_id': 1570423391223484416,
#       'source_status_id_str': '1570423391223484416',
#       'source_user_id': 149669367,
#       'source_user_id_str': '149669367'}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1261566455369420800,
#     'id_str': '1261566455369420800',
#     'name': 'HarmonyOs \uea00',
#     'screen_name': 'sOynomraH',
#     'location': '',
#     'description': 'Amateur',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 119,
#     'friends_count': 272,
#     'listed_count': 1,
#     'created_at': 'Sat May 16 07:58:09 +0000 2020',
#     'favourites_count': 4036,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 4414,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1547868010387365891/orIrE0Gz_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1547868010387365891/orIrE0Gz_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1261566455369420800/1621176015',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Sep 15 14:44:48 +0000 2022',
#     'id': 1570423391223484416,
#     'id_str': '1570423391223484416',
#     'text': '#Apple #iPhone #iPhone14Pro #iPhone14ProMax \n\nThis is the new iPhone 14 Pro Ultra \n\n😬 https://t.co/VYX9OA4A3X',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'Apple', 'indices': [0, 6]},
#       {'text': 'iPhone', 'indices': [7, 14]},
#       {'text': 'iPhone14Pro', 'indices': [15, 27]},
#       {'text': 'iPhone14ProMax', 'indices': [28, 43]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1570423380519669761,
#        'id_str': '1570423380519669761',
#        'indices': [86, 109],
#        'media_url': 'http://pbs.twimg.com/media/FctDvn7X0AE6LJU.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/FctDvn7X0AE6LJU.jpg',
#        'url': 'https://t.co/VYX9OA4A3X',
#        'display_url': 'pic.twitter.com/VYX9OA4A3X',
#        'expanded_url': 'https://twitter.com/AR72014/status/1570423391223484416/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 2048, 'h': 2048, 'resize': 'fit'},
#         'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 680, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1570423380519669761,
#        'id_str': '1570423380519669761',
#        'indices': [86, 109],
#        'media_url': 'http://pbs.twimg.com/media/FctDvn7X0AE6LJU.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/FctDvn7X0AE6LJU.jpg',
#        'url': 'https://t.co/VYX9OA4A3X',
#        'display_url': 'pic.twitter.com/VYX9OA4A3X',
#        'expanded_url': 'https://twitter.com/AR72014/status/1570423391223484416/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 2048, 'h': 2048, 'resize': 'fit'},
#         'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 680, 'resize': 'fit'}}}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 149669367,
#      'id_str': '149669367',
#      'name': 'AR7',
#      'screen_name': 'AR72014',
#      'location': '',
#      'description': '\uf8ff Fan 🇮🇹 | Graphic Designer👨🏻\u200d💻 | iOS beta Tester 📱 Apps & Tech Products Reviews 📸',
#      'url': 'https://t.co/r58ESNjuDW',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/r58ESNjuDW',
#          'expanded_url': 'https://bio.link/ar7',
#          'display_url': 'bio.link/ar7',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 71788,
#      'friends_count': 35,
#      'listed_count': 708,
#      'created_at': 'Sat May 29 22:32:38 +0000 2010',
#      'favourites_count': 129,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 57642,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1534173355431043072/AOtRGVFS_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1534173355431043072/AOtRGVFS_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/149669367/1661463958',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 4,
#     'favorite_count': 19,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 4,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Sep 15 14:53:13 +0000 2022',
#    'id': 1570425511876362240,
#    'id_str': '1570425511876362240',
#    'text': 'RT @nieANTYfan: Tak się złożyło, że będę miał jutro dwa 2x #iPhone14Pro Space Black 256GB. \n\nOba nowe, zafoliowane. Jeżeli ktoś ma jakiś dł…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'iPhone14Pro', 'indices': [59, 71]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'nieANTYfan',
#       'name': 'nieantyfan',
#       'id': 457103688,
#       'id_str': '457103688',
#       'indices': [3, 14]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'pl', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2993111590,
#     'id_str': '2993111590',
#     'name': 'Dominika',
#     'screen_name': 'misia_domi',
#     'location': '',
#     'description': 'Fanka technologii, gadżetów i gier. Gram na #NintendoSwitchOled oraz #XboxSeriesX Czasami tańczę i się wygłupiam 🤭 Gadam na Youtubie o technologii',
#     'url': 'https://t.co/8rPjB7A6hK',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/8rPjB7A6hK',
#         'expanded_url': 'https://www.youtube.com/c/MisiaiTechnologia',
#         'display_url': 'youtube.com/c/MisiaiTechno…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1180,
#     'friends_count': 328,
#     'listed_count': 5,
#     'created_at': 'Thu Jan 22 21:55:35 +0000 2015',
#     'favourites_count': 24370,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 11804,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': True,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1564589012655931393/ZQOvI1s9_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1564589012655931393/ZQOvI1s9_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2993111590/1604301461',
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Sep 15 11:29:18 +0000 2022',
#     'id': 1570374191433531394,
#     'id_str': '1570374191433531394',
#     'text': 'Tak się złożyło, że będę miał jutro dwa 2x #iPhone14Pro Space Black 256GB. \n\nOba nowe, zafoliowane. Jeżeli ktoś ma… https://t.co/Jrbyupp1PT',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'iPhone14Pro', 'indices': [43, 55]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/Jrbyupp1PT',
#        'expanded_url': 'https://twitter.com/i/web/status/1570374191433531394',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'pl', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 457103688,
#      'id_str': '457103688',
#      'name': 'nieantyfan',
#      'screen_name': 'nieANTYfan',
#      'location': 'Wrocław',
#      'description': 'Kiedyś wstydziłem się być nerdem. Teraz wstyd mi o tym nie mówić.',
#      'url': 'https://t.co/HZyAt4whxW',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/HZyAt4whxW',
#          'expanded_url': 'http://youtube.com/c/nieantyfan',
#          'display_url': 'youtube.com/c/nieantyfan',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 22966,
#      'friends_count': 360,
#      'listed_count': 130,
#      'created_at': 'Sat Jan 07 01:20:36 +0000 2012',
#      'favourites_count': 30113,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 39498,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': True,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1518659050946314242/ATkgmEX3_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1518659050946314242/ATkgmEX3_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/457103688/1651596636',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 21,
#     'favorite_count': 96,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'pl'},
#    'is_quote_status': False,
#    'retweet_count': 21,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'pl'},
#   {'created_at': 'Thu Sep 15 14:53:03 +0000 2022',
#    'id': 1570425466783404033,
#    'id_str': '1570425466783404033',
#    'text': 'どうやら14日の夜に発送されてたみたい。\nさっき佐川急便からメールきたわ。\nソフトバンクからはメールない😂\n\nいつも遅い。\n\n#iPhone14pro',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'iPhone14pro', 'indices': [63, 75]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1460146432556814337,
#     'id_str': '1460146432556814337',
#     'name': 'Luna🌙',
#     'screen_name': 'Luna8626',
#     'location': '日本 大阪',
#     'description': 'コスメ・美容がすき！ Diorに散財中💸🤍 イエベ春🌸乾燥肌 / 30↑ 同じ趣味の人と繋がりたい\U0001f979💞コスメ以外のこともボヤきます\U0001faf6',
#     'url': 'https://t.co/Gkiuv3LnWK',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/Gkiuv3LnWK',
#         'expanded_url': 'https://lipscosme.com/users/1462204',
#         'display_url': 'lipscosme.com/users/1462204',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 645,
#     'friends_count': 188,
#     'listed_count': 13,
#     'created_at': 'Mon Nov 15 07:23:42 +0000 2021',
#     'favourites_count': 5847,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2359,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1570314904892248066/11kVnz39_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1570314904892248066/11kVnz39_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1460146432556814337/1636961863',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ja'},
#   {'created_at': 'Thu Sep 15 14:52:41 +0000 2022',
#    'id': 1570425377025056770,
#    'id_str': '1570425377025056770',
#    'text': 'RT @SPIDEReGAMES: #CONCOURS \n🎁 Tentez de gagner un IPhone 14 Pro !\n\nPour participer : Like + RT + follow \n@SPIDEReGAMES \n@levraizarkx &amp; @Ma…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'CONCOURS', 'indices': [18, 27]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SPIDEReGAMES',
#       'name': 'Spider Games',
#       'id': 1100741938184142850,
#       'id_str': '1100741938184142850',
#       'indices': [3, 16]},
#      {'screen_name': 'SPIDEReGAMES',
#       'name': 'Spider Games',
#       'id': 1100741938184142850,
#       'id_str': '1100741938184142850',
#       'indices': [106, 119]},
#      {'screen_name': 'levraizarkx',
#       'name': 'ZarKx \uea00',
#       'id': 1550562701243518977,
#       'id_str': '1550562701243518977',
#       'indices': [121, 133]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 826089498052272130,
#     'id_str': '826089498052272130',
#     'name': 'T1MART1',
#     'screen_name': 'jdeconne__',
#     'location': '',
#     'description': "Y a plus rien d'attachant donc pourquoi ça t'enchante ? Le côté l'plus tranchant, j'ai des p'tits penchants 🎭",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 42,
#     'friends_count': 851,
#     'listed_count': 0,
#     'created_at': 'Mon Jan 30 15:27:39 +0000 2017',
#     'favourites_count': 12101,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 260,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1547704332916666368/PS38Dilr_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1547704332916666368/PS38Dilr_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/826089498052272130/1553096448',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Sep 15 13:50:58 +0000 2022',
#     'id': 1570409845370626050,
#     'id_str': '1570409845370626050',
#     'text': '#CONCOURS \n🎁 Tentez de gagner un IPhone 14 Pro !\n\nPour participer : Like + RT + follow \n@SPIDEReGAMES \n@levraizarkx… https://t.co/Zopp3JKABu',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'CONCOURS', 'indices': [0, 9]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'SPIDEReGAMES',
#        'name': 'Spider Games',
#        'id': 1100741938184142850,
#        'id_str': '1100741938184142850',
#        'indices': [88, 101]},
#       {'screen_name': 'levraizarkx',
#        'name': 'ZarKx \uea00',
#        'id': 1550562701243518977,
#        'id_str': '1550562701243518977',
#        'indices': [103, 115]}],
#      'urls': [{'url': 'https://t.co/Zopp3JKABu',
#        'expanded_url': 'https://twitter.com/i/web/status/1570409845370626050',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1100741938184142850,
#      'id_str': '1100741938184142850',
#      'name': 'Spider Games',
#      'screen_name': 'SPIDEReGAMES',
#      'location': 'Sinon Go 200K ',
#      'description': '❤ les gagnants seront affichés sur mon Instagram : spiderr_gamess ❤️',
#      'url': 'https://t.co/nr3LhcimWD',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/nr3LhcimWD',
#          'expanded_url': 'https://www.youtube.com/c/SPIDERGAMESSS/featured',
#          'display_url': 'youtube.com/c/SPIDERGAMESS…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 3277,
#      'friends_count': 29,
#      'listed_count': 0,
#      'created_at': 'Wed Feb 27 12:58:23 +0000 2019',
#      'favourites_count': 455,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 302,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1569599107760590848/G-IRjFJj_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1569599107760590848/G-IRjFJj_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1100741938184142850/1663056576',
#      'profile_link_color': '981CEB',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 18,
#     'favorite_count': 18,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'fr'},
#    'is_quote_status': False,
#    'retweet_count': 18,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'fr'},
#   {'created_at': 'Thu Sep 15 14:52:31 +0000 2022',
#    'id': 1570425332687343617,
#    'id_str': '1570425332687343617',
#    'text': 'RT @SPIDEReGAMES: #CONCOURS !\n🎁 Tentez de gagner un IPhone 14 Pro Max !\n\nPour participer : RT + likes + follow \n@SPIDEReGAMES \n@levraizarkx…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'CONCOURS', 'indices': [18, 27]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SPIDEReGAMES',
#       'name': 'Spider Games',
#       'id': 1100741938184142850,
#       'id_str': '1100741938184142850',
#       'indices': [3, 16]},
#      {'screen_name': 'SPIDEReGAMES',
#       'name': 'Spider Games',
#       'id': 1100741938184142850,
#       'id_str': '1100741938184142850',
#       'indices': [112, 125]},
#      {'screen_name': 'levraizarkx',
# ...
#      'favourites_count': 455,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 302,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1569599107760590848/G-IRjFJj_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1569599107760590848/G-IRjFJj_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1100741938184142850/1663056576',
#      'profile_link_color': '981CEB',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 18,
#     'favorite_count': 18,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'fr'},
#    'is_quote_status': False,
#    'retweet_count': 18,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'fr'},
#   {'created_at': 'Thu Sep 15 14:51:41 +0000 2022',
#    'id': 1570425123697573888,
#    'id_str': '1570425123697573888',
#    'text': 'RT @Hk3ToN: Prod. By \n@Hk3ToN\n\n#Wallpapers #Apple #iphone #iOS16 #iPhone14 #iPhone14Pro #iPhone14ProMax https://t.co/ne4Rlh02sT',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Wallpapers', 'indices': [31, 42]},
#      {'text': 'Apple', 'indices': [43, 49]},
#      {'text': 'iphone', 'indices': [50, 57]},
#      {'text': 'iOS16', 'indices': [58, 64]},
#      {'text': 'iPhone14', 'indices': [65, 74]},
#      {'text': 'iPhone14Pro', 'indices': [75, 87]},
#      {'text': 'iPhone14ProMax', 'indices': [88, 103]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Hk3ToN',
#       'name': 'ᎻᏦ3ᎢᎾᏁ',
#       'id': 270981443,
#       'id_str': '270981443',
#       'indices': [3, 10]},
#      {'screen_name': 'Hk3ToN',
#       'name': 'ᎻᏦ3ᎢᎾᏁ',
#       'id': 270981443,
#       'id_str': '270981443',
#       'indices': [22, 29]}],
#     'urls': [],
#     'media': [{'id': 1570422125441212417,
#       'id_str': '1570422125441212417',
#       'indices': [104, 127],
#       'media_url': 'http://pbs.twimg.com/media/FctCmkZWYAEh9tI.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/FctCmkZWYAEh9tI.jpg',
#       'url': 'https://t.co/ne4Rlh02sT',
#       'display_url': 'pic.twitter.com/ne4Rlh02sT',
#       'expanded_url': 'https://twitter.com/Hk3ToN/status/1570422133016383494/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 737, 'resize': 'fit'},
#        'large': {'w': 1303, 'h': 800, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 417, 'resize': 'fit'}},
#       'source_status_id': 1570422133016383494,
#       'source_status_id_str': '1570422133016383494',
#       'source_user_id': 270981443,
#       'source_user_id_str': '270981443'}]},
#    'extended_entities': {'media': [{'id': 1570422125441212417,
#       'id_str': '1570422125441212417',
#       'indices': [104, 127],
#       'media_url': 'http://pbs.twimg.com/media/FctCmkZWYAEh9tI.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/FctCmkZWYAEh9tI.jpg',
#       'url': 'https://t.co/ne4Rlh02sT',
#       'display_url': 'pic.twitter.com/ne4Rlh02sT',
#       'expanded_url': 'https://twitter.com/Hk3ToN/status/1570422133016383494/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 737, 'resize': 'fit'},
#        'large': {'w': 1303, 'h': 800, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 417, 'resize': 'fit'}},
#       'source_status_id': 1570422133016383494,
#       'source_status_id_str': '1570422133016383494',
#       'source_user_id': 270981443,
#       'source_user_id_str': '270981443'},
#      {'id': 1570422125483233282,
#       'id_str': '1570422125483233282',
#       'indices': [104, 127],
#       'media_url': 'http://pbs.twimg.com/media/FctCmkjXkAImnEs.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/FctCmkjXkAImnEs.jpg',
#       'url': 'https://t.co/ne4Rlh02sT',
#       'display_url': 'pic.twitter.com/ne4Rlh02sT',
#       'expanded_url': 'https://twitter.com/Hk3ToN/status/1570422133016383494/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1303, 'h': 800, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 737, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 417, 'resize': 'fit'}},
#       'source_status_id': 1570422133016383494,
#       'source_status_id_str': '1570422133016383494',
#       'source_user_id': 270981443,
#       'source_user_id_str': '270981443'}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1455422208877240321,
#     'id_str': '1455422208877240321',
#     'name': 'Nail Beglov',
#     'screen_name': 'NailBeglov',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3,
#     'friends_count': 28,
#     'listed_count': 0,
#     'created_at': 'Tue Nov 02 06:31:51 +0000 2021',
#     'favourites_count': 172,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 187,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1455422386149416964/YQxgxdVJ_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1455422386149416964/YQxgxdVJ_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Sep 15 14:39:48 +0000 2022',
#     'id': 1570422133016383494,
#     'id_str': '1570422133016383494',
#     'text': 'Prod. By \n@Hk3ToN\n\n#Wallpapers #Apple #iphone #iOS16 #iPhone14 #iPhone14Pro #iPhone14ProMax https://t.co/ne4Rlh02sT',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'Wallpapers', 'indices': [19, 30]},
#       {'text': 'Apple', 'indices': [31, 37]},
#       {'text': 'iphone', 'indices': [38, 45]},
#       {'text': 'iOS16', 'indices': [46, 52]},
#       {'text': 'iPhone14', 'indices': [53, 62]},
#       {'text': 'iPhone14Pro', 'indices': [63, 75]},
#       {'text': 'iPhone14ProMax', 'indices': [76, 91]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'Hk3ToN',
#        'name': 'ᎻᏦ3ᎢᎾᏁ',
#        'id': 270981443,
#        'id_str': '270981443',
#        'indices': [10, 17]}],
#      'urls': [],
#      'media': [{'id': 1570422125441212417,
#        'id_str': '1570422125441212417',
#        'indices': [92, 115],
#        'media_url': 'http://pbs.twimg.com/media/FctCmkZWYAEh9tI.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/FctCmkZWYAEh9tI.jpg',
#        'url': 'https://t.co/ne4Rlh02sT',
#        'display_url': 'pic.twitter.com/ne4Rlh02sT',
#        'expanded_url': 'https://twitter.com/Hk3ToN/status/1570422133016383494/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 737, 'resize': 'fit'},
#         'large': {'w': 1303, 'h': 800, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 417, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1570422125441212417,
#        'id_str': '1570422125441212417',
#        'indices': [92, 115],
#        'media_url': 'http://pbs.twimg.com/media/FctCmkZWYAEh9tI.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/FctCmkZWYAEh9tI.jpg',
#        'url': 'https://t.co/ne4Rlh02sT',
#        'display_url': 'pic.twitter.com/ne4Rlh02sT',
#        'expanded_url': 'https://twitter.com/Hk3ToN/status/1570422133016383494/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 737, 'resize': 'fit'},
#         'large': {'w': 1303, 'h': 800, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 417, 'resize': 'fit'}}},
#       {'id': 1570422125483233282,
#        'id_str': '1570422125483233282',
#        'indices': [92, 115],
#        'media_url': 'http://pbs.twimg.com/media/FctCmkjXkAImnEs.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/FctCmkjXkAImnEs.jpg',
#        'url': 'https://t.co/ne4Rlh02sT',
#        'display_url': 'pic.twitter.com/ne4Rlh02sT',
#        'expanded_url': 'https://twitter.com/Hk3ToN/status/1570422133016383494/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 1303, 'h': 800, 'resize': 'fit'},
#         'medium': {'w': 1200, 'h': 737, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 417, 'resize': 'fit'}}}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 270981443,
#      'id_str': '270981443',
#      'name': 'ᎻᏦ3ᎢᎾᏁ',
#      'screen_name': 'Hk3ToN',
#      'location': 'France',
#      'description': 'Contribution or access Links, click on the link below',
#      'url': 'https://t.co/oNut3acgGW',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/oNut3acgGW',
#          'expanded_url': 'https://linksome.me/hk3ton',
#          'display_url': 'linksome.me/hk3ton',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 8466,
#      'friends_count': 33,
#      'listed_count': 82,
#      'created_at': 'Wed Mar 23 16:35:39 +0000 2011',
#      'favourites_count': 1570,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 6952,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1278264820450680833/LKoAc7nh_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1278264820450680833/LKoAc7nh_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/270981443/1593597057',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Sep 15 14:51:01 +0000 2022',
#    'id': 1570424956646821888,
#    'id_str': '1570424956646821888',
#    'text': 'Apple said my #iphone14Pro max would be here by the 23rd but tracking says it’ll be here tomorrow!! Ahhhhh',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'iphone14Pro', 'indices': [14, 26]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 18597162,
#     'id_str': '18597162',
#     'name': 'Chason',
#     'screen_name': 'chasonstone',
#     'location': 'Tennessee, USA',
#     'description': '🏳️\u200d🌈 it probably wasn’t that serious',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 273,
#     'friends_count': 235,
#     'listed_count': 6,
#     'created_at': 'Sun Jan 04 06:17:38 +0000 2009',
#     'favourites_count': 2549,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 4797,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1537794652509720576/K-lBGlLl_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1537794652509720576/K-lBGlLl_normal.jpg',
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.079,
#   'max_id': 1570426680224935937,
#   'max_id_str': '1570426680224935937',
#   'next_results': '?max_id=1570424956646821887&q=%23iPhone14Pro&include_entities=1',
#   'query': '%23iPhone14Pro',
#   'refresh_url': '?since_id=1570426680224935937&q=%23iPhone14Pro&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %% [markdown]
# ### Loading credentials and Tweepy authentication

# %%
# read configs

config = configparser.ConfigParser()
config.read('../../../config_files/config.ini')

api_key = config['twitter']['api_key']
api_key_secret = config['twitter']['api_key_secret']

access_token = config['twitter']['access_token']
access_token_secret = config['twitter']['access_token_secret']

# %%
# authentication

auth = tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %% [markdown]
# ### Data gathering from Twitter API

# %% [markdown]
# #### Option 1

# %%
# search by user

# user = 'veritasium'
# limit=300
# tweets = tweepy.Cursor(api.user_timeline, screen_name=user, count=200, tweet_mode='extended').items(limit)

# search by keyword or hashtag (works too for @user)
keywords = "#iPhone14Pro -filter:retweets"
limit = 10000
tweets = tweepy.Cursor(
    api.search_tweets, q=keywords, count=100, lang="en", tweet_mode="extended").items(limit)

# create DataFrame
columns = [
    "User",
    "Tweet_time",
    "Tweet",
    "Hashtag",
    "Retweet",
    "Favorite",
    "Join_time",
    "Follower",
    "Friend",
]

data = []

for tweet in tweets:
    data.append(
        [
            tweet.user.screen_name,
            tweet.created_at,
            tweet.full_text,
            tweet.entities["hashtags"],
            tweet.retweet_count,
            tweet.favorite_count,
            tweet.user.created_at,
            tweet.user.followers_count,
            tweet.user.friends_count,
        ]
    )

df = pd.DataFrame(data, columns=columns)

df.head()
# Out:
#            User                Tweet_time  \
# 0   mivhunter26 2022-09-15 13:38:05+00:00
# 1  ElartistaKha 2022-09-15 13:37:25+00:00
# 2       Moto760 2022-09-15 13:36:40+00:00
# 3       MrGfUnK 2022-09-15 13:35:07+00:00
# 4  _Apps4World_ 2022-09-15 13:32:41+00:00
#
#                                                Tweet  \
# 0  This is what I’m excited about today: \n\n#iPh...
# 1  I like older women, attracted to older woman, ...
# 2  Well, finally!  I got a ship notification. Too...
# 3  My #iPhone14ProMax &amp; #iPhone14Pro have bee...
# 4  🚀 Launcher for iOS 16 Lock Screen 🔥\n\nFull Sw...
#
#                                              Hashtag  Retweet  Favorite  \
# 0  [{'text': 'iPhone14Pro', 'indices': [40, 52]},...        0         0
# 1  [{'text': 'shirt', 'indices': [164, 170]}, {'t...        0         0
# 2  [{'text': 'Apple', 'indices': [64, 70]}, {'tex...        0         0
# 3  [{'text': 'iPhone14ProMax', 'indices': [3, 18]...        0         0
# 4  [{'text': 'iPhone14Pro', 'indices': [88, 100]}...        0         0
#
#                   Join_time  Follower  Friend
# 0 2008-03-28 06:29:59+00:00       135     271
# 1 2021-10-19 11:18:03+00:00         0       8
# 2 2020-04-20 12:27:35+00:00      1275     283
# 3 2009-10-31 20:33:37+00:00       333     411
# 4 2021-10-10 14:15:29+00:00        16       0

# %% [markdown]
# #### Option 2

# %%
# gathering data from API

keywords = '#iPhone14Pro'
limit = 10000

tweets = tweepy.Cursor(api.search_tweets, q=keywords, lang='en', count=100,
                       tweet_mode='extended').items(limit)

# creating DataFrame

columns = ['User', 'DateTime', 'Tweet']
data = []

for tweet in tweets:
    data.append([tweet.user.screen_name, tweet.created_at, tweet.full_text])
    
df = pd.DataFrame(data, columns=columns)

df.head()
# Out:
#             User                  DateTime  \
# 0    mivhunter26 2022-09-15 13:38:05+00:00
# 1  osanagikazami 2022-09-15 13:37:57+00:00
# 2   yamamiharuna 2022-09-15 13:37:57+00:00
# 3   ElartistaKha 2022-09-15 13:37:25+00:00
# 4        Moto760 2022-09-15 13:36:40+00:00
#
#                                                Tweet
# 0  This is what I’m excited about today: \n\n#iPh...
# 1  RT @explicitgzz: COURTSIDE OUT NOW ON ALL PLAT...
# 2  RT @explicitgzz: COURTSIDE OUT NOW ON ALL PLAT...
# 3  I like older women, attracted to older woman, ...
# 4  Well, finally!  I got a ship notification. Too...

# %% [markdown]
# ### Test

# %%
# RUN THIS IS IT WORKED
# df.to_csv('../data/raw/TEST50K.csv

# %% [markdown]
# ### Reading DataFrame for iPhone 14 Pro

# %%
#df.to_csv('../data/raw/iPhone14Prox10k_RAW_2.csv)

# %%
df14pro = pd.read_csv('../data/raw/iPhone14Prox10k_RAW.csv')
df14pro.head()
# Out:
#    Unnamed: 0             User                   DateTime  \
# 0           0         1202tung  2022-09-14 14:48:27+00:00
# 1           1  Rushike74038427  2022-09-14 14:48:05+00:00
# 2           2          papsobu  2022-09-14 14:47:40+00:00
# 3           3    _kayrozenlang  2022-09-14 14:47:27+00:00
# 4           4     SarenDebnath  2022-09-14 14:46:41+00:00
#
#                                                Tweet
# 0  RT @insanetweet: iPhone 8 while upgrading to i...
# 1  I want this case @Mrwhosetheboss \n#iphone14pr...
# 2  RT @insanetweet: iPhone 8 while upgrading to i...
# 3  RT @btslabs_global: 🏆Win iPhone14 Pro\n\nWith ...
# 4  RT @btslabs_global: 🏆Win iPhone14 Pro\n\nWith ...

# %%
df14pro['User'].value_counts()
# Out:
# thebbmafrica       63
# ChronicallyTG      41
# FaizanA17120449    40
# XXFemale1          39
# sgmobmart          34
#                    ..
# p_929303            1
# bonxcviii           1
# twtfnov             1
# axososad            1
# Getpaidrealquic     1
# Name: User, Length: 8703, dtype: int64

# %% [markdown]
# ### Cleaning Tweet Column

# %%
df14pro['Tweet'][0]
# Out:
# 'RT @insanetweet: iPhone 8 while upgrading to iOS 16\n\n#iOS16 #iPhone14 #iPhone14Pro \n https://t.co/IOpAaBnHus'

# %%
"""import re
import string

text = df14pro['Tweet'][0]
remove = string.punctuation
remove = remove.replace('#', '')
pattern = r"[{}]".format(remove)

re.sub(pattern, '', text)"""
# Out:
# 'import re\nimport string\n\ntext = df14pro[\'Tweet\'][0]\nremove = string.punctuation\nremove = remove.replace(\'#\', \'\')\npattern = r"[{}]".format(remove)\n\nre.sub(pattern, \'\', text)'

# %%
# removing punctuations and lowercase normalization
import string
text = df14pro['Tweet'][0]
text_clean1 = ''.join([i.lower() for i in text if i not in string.punctuation])
text_clean1
# Out:
# 'rt insanetweet iphone 8 while upgrading to ios 16\n\nios16 iphone14 iphone14pro \n httpstcoiopaabnhus'

# %%
# removing \n
import re
text_clean2 = re.sub('\n', ' ' , text_clean1)
text_clean2
# Out:
# 'rt insanetweet iphone 8 while upgrading to ios 16  ios16 iphone14 iphone14pro   httpstcoiopaabnhus'

# %%
# removing url
text_clean3 = result = re.sub(r'http\S+', '', text_clean2)
text_clean3
# Out:
# 'rt insanetweet iphone 8 while upgrading to ios 16  ios16 iphone14 iphone14pro   '

# %%
# importing stopwords
import nltk
from nltk.corpus import stopwords
cachedStopWords = stopwords.words('english')
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# removing stopwords
text_clean4 = ' '.join([word for word in text_clean3.split() if word not in stopwords.words('english')])
print(text)
# Out:
# RT @insanetweet: iPhone 8 while upgrading to iOS 16
#
# #iOS16 #iPhone14 #iPhone14Pro
#  https://t.co/IOpAaBnHus

# %%
# counting single words within a string
def word_count(str):
    counts = dict()
    words = str.split()
    
    for word in words:
        if word in counts:
            counts[word] += 1
        else:
            counts[word] = 1
    return counts

print(word_count(text_clean4))
# Out:
# {'rt': 1, 'insanetweet': 1, 'iphone': 1, '8': 1, 'upgrading': 1, 'ios': 1, '16': 1, 'ios16': 1, 'iphone14': 1, 'iphone14pro': 1}

# %% [markdown]
# ### Creating boolean for retweets

# %%
df14pro.head()
# Out:
#    Unnamed: 0             User                   DateTime  \
# 0           0         1202tung  2022-09-14 14:48:27+00:00
# 1           1  Rushike74038427  2022-09-14 14:48:05+00:00
# 2           2          papsobu  2022-09-14 14:47:40+00:00
# 3           3    _kayrozenlang  2022-09-14 14:47:27+00:00
# 4           4     SarenDebnath  2022-09-14 14:46:41+00:00
#
#                                                Tweet
# 0  RT @insanetweet: iPhone 8 while upgrading to i...
# 1  I want this case @Mrwhosetheboss \n#iphone14pr...
# 2  RT @insanetweet: iPhone 8 while upgrading to i...
# 3  RT @btslabs_global: 🏆Win iPhone14 Pro\n\nWith ...
# 4  RT @btslabs_global: 🏆Win iPhone14 Pro\n\nWith ...

# %%
df14pro['Retweet'] = df14pro['Tweet'].str.contains('RT @')
df14pro
# Out:
#       Unnamed: 0             User                   DateTime  \
# 0              0         1202tung  2022-09-14 14:48:27+00:00
# 1              1  Rushike74038427  2022-09-14 14:48:05+00:00
# 2              2          papsobu  2022-09-14 14:47:40+00:00
# 3              3    _kayrozenlang  2022-09-14 14:47:27+00:00
# 4              4     SarenDebnath  2022-09-14 14:46:41+00:00
# ...          ...              ...                        ...
# 9995        9995      techonthego  2022-09-10 08:54:17+00:00
# 9996        9996        PappannaG  2022-09-10 08:52:39+00:00
# 9997        9997      dynamo_mano  2022-09-10 08:52:24+00:00
# 9998        9998      spotter81au  2022-09-10 08:52:07+00:00
# 9999        9999  Getpaidrealquic  2022-09-10 08:51:15+00:00
#
#                                                   Tweet  Retweet
# 0     RT @insanetweet: iPhone 8 while upgrading to i...     True
# 1     I want this case @Mrwhosetheboss \n#iphone14pr...    False
# 2     RT @insanetweet: iPhone 8 while upgrading to i...     True
# 3     RT @btslabs_global: 🏆Win iPhone14 Pro\n\nWith ...     True
# 4     RT @btslabs_global: 🏆Win iPhone14 Pro\n\nWith ...     True
# ...                                                 ...      ...
# 9995  Pre-order the amazing new iPhone 14 Pro on the...    False
# 9996  RT @Drife_official: iPhone users, assemble?! 😅...     True
# 9997  RT @Jazzy4Tech_: Yesterday, I went to Croma re...     True
# 9998  Perfect! #iPhone14pro #dynamicisland https://t...    False
# 9999  RT @BIGWIZZY25: Na your boyfriend wey dey sell...     True
#
# [10000 rows x 5 columns]

# %%
df14pro['Retweet'].value_counts()
# Out:
# True     7967
# False    2033
# Name: Retweet, dtype: int64

# %%
df14pro['Tweet'][1]
# Out:
# 'I want this case @Mrwhosetheboss \n#iphone14pro #iphone14procase #iphone14ProMax https://t.co/vkJB0EICT1'

# %%
df14pro['Retweet'][1]
# Out:
# False

# %%
df14pro['Tweet'] = df14pro['Tweet'].str.lower()
df14pro
# Out:
#       Unnamed: 0             User                   DateTime  \
# 0              0         1202tung  2022-09-14 14:48:27+00:00
# 1              1  Rushike74038427  2022-09-14 14:48:05+00:00
# 2              2          papsobu  2022-09-14 14:47:40+00:00
# 3              3    _kayrozenlang  2022-09-14 14:47:27+00:00
# 4              4     SarenDebnath  2022-09-14 14:46:41+00:00
# ...          ...              ...                        ...
# 9995        9995      techonthego  2022-09-10 08:54:17+00:00
# 9996        9996        PappannaG  2022-09-10 08:52:39+00:00
# 9997        9997      dynamo_mano  2022-09-10 08:52:24+00:00
# 9998        9998      spotter81au  2022-09-10 08:52:07+00:00
# 9999        9999  Getpaidrealquic  2022-09-10 08:51:15+00:00
#
#                                                   Tweet  Retweet
# 0     rt @insanetweet: iphone 8 while upgrading to i...     True
# 1     i want this case @mrwhosetheboss \n#iphone14pr...    False
# 2     rt @insanetweet: iphone 8 while upgrading to i...     True
# 3     rt @btslabs_global: 🏆win iphone14 pro\n\nwith ...     True
# 4     rt @btslabs_global: 🏆win iphone14 pro\n\nwith ...     True
# ...                                                 ...      ...
# 9995  pre-order the amazing new iphone 14 pro on the...    False
# 9996  rt @drife_official: iphone users, assemble?! 😅...     True
# 9997  rt @jazzy4tech_: yesterday, i went to croma re...     True
# 9998  perfect! #iphone14pro #dynamicisland https://t...    False
# 9999  rt @bigwizzy25: na your boyfriend wey dey sell...     True
#
# [10000 rows x 5 columns]

# %%
#from functools import reduce
#filters = [("#iphone14", False), ("#iphone14pro", True)]
#df14pro['#iphone14'] = reduce(lambda df14pro, f: df14pro[df14pro.str.contains(f[0]) == f[1]], filters, df14pro)

# %%
#df14pro['#iphone14'] = df14pro[(df14pro['#iphone14'].str.contains('#iphone14')) & (~df14pro['#iphone14'].str.contains('upgrading'))]

# %%
#df14pro['#iphone14'] = df14pro[(df14pro.str.contains('#iphone14') == True) and (df14pro.str.contains('#iphone14pro') == False)]
#df14pro

# %%
#df14pro['#iphone14'] = np.where(df14pro['Tweet'].eq('iphone14'), 'true', 'false')
#df14pro

# %%
#df14pro['#iphone14'].value_counts()

# %%
df14pro['#iphone14'] = df14pro['Tweet'].apply(lambda x: '#iphone14' in x and 'iphone14pro' not in x)
df14pro
# Out:
#       Unnamed: 0             User                   DateTime  \
# 0              0         1202tung  2022-09-14 14:48:27+00:00
# 1              1  Rushike74038427  2022-09-14 14:48:05+00:00
# 2              2          papsobu  2022-09-14 14:47:40+00:00
# 3              3    _kayrozenlang  2022-09-14 14:47:27+00:00
# 4              4     SarenDebnath  2022-09-14 14:46:41+00:00
# ...          ...              ...                        ...
# 9995        9995      techonthego  2022-09-10 08:54:17+00:00
# 9996        9996        PappannaG  2022-09-10 08:52:39+00:00
# 9997        9997      dynamo_mano  2022-09-10 08:52:24+00:00
# 9998        9998      spotter81au  2022-09-10 08:52:07+00:00
# 9999        9999  Getpaidrealquic  2022-09-10 08:51:15+00:00
#
#                                                   Tweet  Retweet  #iphone14
# 0     rt @insanetweet: iphone 8 while upgrading to i...     True      False
# 1     i want this case @mrwhosetheboss \n#iphone14pr...    False      False
# 2     rt @insanetweet: iphone 8 while upgrading to i...     True      False
# 3     rt @btslabs_global: 🏆win iphone14 pro\n\nwith ...     True      False
# 4     rt @btslabs_global: 🏆win iphone14 pro\n\nwith ...     True      False
# ...                                                 ...      ...        ...
# 9995  pre-order the amazing new iphone 14 pro on the...    False      False
# 9996  rt @drife_official: iphone users, assemble?! 😅...     True      False
# 9997  rt @jazzy4tech_: yesterday, i went to croma re...     True      False
# 9998  perfect! #iphone14pro #dynamicisland https://t...    False      False
# 9999  rt @bigwizzy25: na your boyfriend wey dey sell...     True      False
#
# [10000 rows x 6 columns]

# %%
df14pro['#iphone14'].value_counts()
# Out:
# False    9879
# True      121
# Name: #iphone14, dtype: int64

# %%
df14pro['#iphone14pro'] = df14pro['Tweet'].str.contains('#iphone14pro')
df14pro
# Out:
#       Unnamed: 0             User                   DateTime  \
# 0              0         1202tung  2022-09-14 14:48:27+00:00
# 1              1  Rushike74038427  2022-09-14 14:48:05+00:00
# 2              2          papsobu  2022-09-14 14:47:40+00:00
# 3              3    _kayrozenlang  2022-09-14 14:47:27+00:00
# 4              4     SarenDebnath  2022-09-14 14:46:41+00:00
# ...          ...              ...                        ...
# 9995        9995      techonthego  2022-09-10 08:54:17+00:00
# 9996        9996        PappannaG  2022-09-10 08:52:39+00:00
# 9997        9997      dynamo_mano  2022-09-10 08:52:24+00:00
# 9998        9998      spotter81au  2022-09-10 08:52:07+00:00
# 9999        9999  Getpaidrealquic  2022-09-10 08:51:15+00:00
#
#                                                   Tweet  Retweet  #iphone14  \
# 0     rt @insanetweet: iphone 8 while upgrading to i...     True      False
# 1     i want this case @mrwhosetheboss \n#iphone14pr...    False      False
# 2     rt @insanetweet: iphone 8 while upgrading to i...     True      False
# 3     rt @btslabs_global: 🏆win iphone14 pro\n\nwith ...     True      False
# 4     rt @btslabs_global: 🏆win iphone14 pro\n\nwith ...     True      False
# ...                                                 ...      ...        ...
# 9995  pre-order the amazing new iphone 14 pro on the...    False      False
# 9996  rt @drife_official: iphone users, assemble?! 😅...     True      False
# 9997  rt @jazzy4tech_: yesterday, i went to croma re...     True      False
# 9998  perfect! #iphone14pro #dynamicisland https://t...    False      False
# 9999  rt @bigwizzy25: na your boyfriend wey dey sell...     True      False
#
#       #iphone14pro
# 0             True
# 1             True
# 2             True
# 3             True
# 4             True
# ...            ...
# 9995          True
# 9996          True
# 9997          True
# 9998          True
# 9999          True
#
# [10000 rows x 7 columns]

# %%
df14pro['#iphone14pro'].value_counts()
# Out:
# True     8103
# False    1897
# Name: #iphone14pro, dtype: int64

# %%
df = df14pro[df14pro['#iphone14pro'] == False]
df
# Out:
#       Unnamed: 0           User                   DateTime  \
# 10            10       kamanmpo  2022-09-14 14:43:33+00:00
# 12            12       MrAyitey  2022-09-14 14:41:51+00:00
# 20            20    parvaneh172  2022-09-14 14:38:13+00:00
# 23            23  EkeneChinedum  2022-09-14 14:37:45+00:00
# 36            36     D4_concept  2022-09-14 14:32:58+00:00
# ...          ...            ...                        ...
# 9958        9958    JosephKorex  2022-09-10 09:11:50+00:00
# 9968        9968    Beardedelf1  2022-09-10 09:05:30+00:00
# 9986        9986  mi_konstantin  2022-09-10 08:57:38+00:00
# 9989        9989   theoddgirl18  2022-09-10 08:56:36+00:00
# 9993        9993   ManuelADlove  2022-09-10 08:54:58+00:00
#
#                                                   Tweet  Retweet  #iphone14  \
# 10    rt @ksmolka: who has an iphone 14 pro right no...     True      False
# 12    rt @ksmolka: who has an iphone 14 pro right no...     True      False
# 20    rt @ksmolka: who has an iphone 14 pro right no...     True      False
# 23    rt @olacokers: apple have successfully given m...     True      False
# 36    rt @kellypencil1: i wonder why this my work di...     True      False
# ...                                                 ...      ...        ...
# 9958  rt @pinetworkark: breaking news! \n\na merchan...     True      False
# 9968  rt @kellypencil1: i wonder why this my work di...     True      False
# 9986  rt @ld_vova: i redesigned the iphone 14 pro wa...     True      False
# 9989  rt @idevicehelpus: ios 16 rc &amp; final relea...     True      False
# 9993  rt @vii2xii: they are not looking for money to...     True      False
#
#       #iphone14pro
# 10           False
# 12           False
# 20           False
# 23           False
# 36           False
# ...            ...
# 9958         False
# 9968         False
# 9986         False
# 9989         False
# 9993         False
#
# [1897 rows x 7 columns]

# %%
df['Tweet'][10]
# Out:
# 'rt @ksmolka: who has an iphone 14 pro right now? need to test this on device asap!\n\n🏝️ hit the island - our game concept for iphone 14 pro,…'

# %% [markdown]
# ### Overlap between sets

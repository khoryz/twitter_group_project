# %% [markdown]
# # Twitter API Scraping

# %% [markdown]
# ### Packages to load

# %%
import tweepy
import configparser
import pandas as pd
import numpy as np
import json
from twython import Twython

# %% [markdown]
# ### Other stuff to load

# %%
# nothing

# %% [markdown]
# ### Loading credentials and Twython authentication

# %%
with open("../../../config_files/credentials.json") as infile:
    credentials = json.load(infile)

twitter_client = Twython(credentials["api_key"],
                         credentials["api_secret"],
                         credentials["access_token"],
                         credentials["access_token_secret"])

# %% [markdown]
# ### Data gathering test from Twython

# %%
# trying to gather from Twython

keywords = '#iPhone14Pro'

twitter_client.search(q=keywords)
# Out:
# {'statuses': [{'created_at': 'Wed Sep 14 18:07:07 +0000 2022',
#    'id': 1570111920660938752,
#    'id_str': '1570111920660938752',
#    'text': 'RT @BrandonJHavard: Barney edition #iphone14pro https://t.co/VXGMUCvmNd',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'iphone14pro', 'indices': [35, 47]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'BrandonJHavard',
#       'name': 'Brandon Havard',
#       'id': 324745996,
#       'id_str': '324745996',
#       'indices': [3, 18]}],
#     'urls': [],
#     'media': [{'id': 1570058119694241792,
#       'id_str': '1570058119694241792',
#       'indices': [48, 71],
#       'media_url': 'http://pbs.twimg.com/media/Fcn3ipUX0AA0Npq.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Fcn3ipUX0AA0Npq.jpg',
#       'url': 'https://t.co/VXGMUCvmNd',
#       'display_url': 'pic.twitter.com/VXGMUCvmNd',
#       'expanded_url': 'https://twitter.com/BrandonJHavard/status/1570058128506363906/photo/1',
#       'type': 'photo',
#       'sizes': {'large': {'w': 2048, 'h': 1024, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 600, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 340, 'resize': 'fit'}},
#       'source_status_id': 1570058128506363906,
#       'source_status_id_str': '1570058128506363906',
#       'source_user_id': 324745996,
#       'source_user_id_str': '324745996'}]},
#    'extended_entities': {'media': [{'id': 1570058119694241792,
#       'id_str': '1570058119694241792',
#       'indices': [48, 71],
#       'media_url': 'http://pbs.twimg.com/media/Fcn3ipUX0AA0Npq.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Fcn3ipUX0AA0Npq.jpg',
#       'url': 'https://t.co/VXGMUCvmNd',
#       'display_url': 'pic.twitter.com/VXGMUCvmNd',
#       'expanded_url': 'https://twitter.com/BrandonJHavard/status/1570058128506363906/photo/1',
#       'type': 'photo',
#       'sizes': {'large': {'w': 2048, 'h': 1024, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 600, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 340, 'resize': 'fit'}},
#       'source_status_id': 1570058128506363906,
#       'source_status_id_str': '1570058128506363906',
#       'source_user_id': 324745996,
#       'source_user_id_str': '324745996'},
#      {'id': 1570058119517970440,
#       'id_str': '1570058119517970440',
#       'indices': [48, 71],
#       'media_url': 'http://pbs.twimg.com/media/Fcn3ioqWIAgV1fl.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Fcn3ioqWIAgV1fl.jpg',
#       'url': 'https://t.co/VXGMUCvmNd',
#       'display_url': 'pic.twitter.com/VXGMUCvmNd',
#       'expanded_url': 'https://twitter.com/BrandonJHavard/status/1570058128506363906/photo/1',
#       'type': 'photo',
#       'sizes': {'large': {'w': 2048, 'h': 1024, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 600, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 340, 'resize': 'fit'}},
#       'source_status_id': 1570058128506363906,
#       'source_status_id_str': '1570058128506363906',
#       'source_user_id': 324745996,
#       'source_user_id_str': '324745996'}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2815101032,
#     'id_str': '2815101032',
#     'name': 'Sarthak Jain',
#     'screen_name': 'jainsarthak99',
#     'location': 'Indore',
#     'description': 'Chartered Accountant & Tech Enthusiast.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 907,
#     'friends_count': 3246,
#     'listed_count': 0,
#     'created_at': 'Wed Sep 17 15:13:49 +0000 2014',
#     'favourites_count': 18600,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 2301,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1536747674740961281/ycXcD0xT_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1536747674740961281/ycXcD0xT_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2815101032/1620754879',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Sep 14 14:33:22 +0000 2022',
#     'id': 1570058128506363906,
#     'id_str': '1570058128506363906',
#     'text': 'Barney edition #iphone14pro https://t.co/VXGMUCvmNd',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'iphone14pro', 'indices': [15, 27]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1570058119694241792,
#        'id_str': '1570058119694241792',
#        'indices': [28, 51],
#        'media_url': 'http://pbs.twimg.com/media/Fcn3ipUX0AA0Npq.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/Fcn3ipUX0AA0Npq.jpg',
#        'url': 'https://t.co/VXGMUCvmNd',
#        'display_url': 'pic.twitter.com/VXGMUCvmNd',
#        'expanded_url': 'https://twitter.com/BrandonJHavard/status/1570058128506363906/photo/1',
#        'type': 'photo',
#        'sizes': {'large': {'w': 2048, 'h': 1024, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 600, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 340, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1570058119694241792,
#        'id_str': '1570058119694241792',
#        'indices': [28, 51],
#        'media_url': 'http://pbs.twimg.com/media/Fcn3ipUX0AA0Npq.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/Fcn3ipUX0AA0Npq.jpg',
#        'url': 'https://t.co/VXGMUCvmNd',
#        'display_url': 'pic.twitter.com/VXGMUCvmNd',
#        'expanded_url': 'https://twitter.com/BrandonJHavard/status/1570058128506363906/photo/1',
#        'type': 'photo',
#        'sizes': {'large': {'w': 2048, 'h': 1024, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 600, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 340, 'resize': 'fit'}}},
#       {'id': 1570058119517970440,
#        'id_str': '1570058119517970440',
#        'indices': [28, 51],
#        'media_url': 'http://pbs.twimg.com/media/Fcn3ioqWIAgV1fl.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/Fcn3ioqWIAgV1fl.jpg',
#        'url': 'https://t.co/VXGMUCvmNd',
#        'display_url': 'pic.twitter.com/VXGMUCvmNd',
#        'expanded_url': 'https://twitter.com/BrandonJHavard/status/1570058128506363906/photo/1',
#        'type': 'photo',
#        'sizes': {'large': {'w': 2048, 'h': 1024, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 600, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 340, 'resize': 'fit'}}}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 324745996,
#      'id_str': '324745996',
#      'name': 'Brandon Havard',
#      'screen_name': 'BrandonJHavard',
#      'location': 'nyc',
#      'description': 'Video Maker | Dog Observer | Creative Director @MKBHD | Powered by Coffee',
#      'url': 'https://t.co/XTsNLgZ7WI',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/XTsNLgZ7WI',
#          'expanded_url': 'http://brandonhavard.com',
#          'display_url': 'brandonhavard.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 33973,
#      'friends_count': 184,
#      'listed_count': 134,
#      'created_at': 'Mon Jun 27 04:23:03 +0000 2011',
#      'favourites_count': 4621,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 5676,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '1A1B1F',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1568679826252337158/WO79gF4B_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1568679826252337158/WO79gF4B_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/324745996/1653165661',
#      'profile_link_color': '2FC2EF',
#      'profile_sidebar_border_color': '181A1E',
#      'profile_sidebar_fill_color': '252429',
#      'profile_text_color': '666666',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 15,
#     'favorite_count': 555,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 15,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Sep 14 18:06:50 +0000 2022',
#    'id': 1570111846165757954,
#    'id_str': '1570111846165757954',
#    'text': 'RT @0xHaz666: #CONCOURS Un iPhone 14 Pro à gagner !\n\nPour participer : RT + follow + like \n\nT.A.S dans 48h ! \n\n#Giveaway #iphone #apple #iP…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'CONCOURS', 'indices': [14, 23]},
#      {'text': 'Giveaway', 'indices': [111, 120]},
#      {'text': 'iphone', 'indices': [121, 128]},
#      {'text': 'apple', 'indices': [129, 135]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': '0xHaz666',
#       'name': 'HAZ 🚀',
#       'id': 1437146065589964803,
#       'id_str': '1437146065589964803',
#       'indices': [3, 12]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1530256873001209856,
#     'id_str': '1530256873001209856',
#     'name': 'Yännissou Mendez',
#     'screen_name': 'MendezYannissou',
#     'location': '',
#     'description': 'Je suis beau',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3,
#     'friends_count': 36,
#     'listed_count': 0,
#     'created_at': 'Fri May 27 18:37:39 +0000 2022',
#     'favourites_count': 171,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 125,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1530256942140116994/TwUcY9eU_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1530256942140116994/TwUcY9eU_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Sep 08 10:08:55 +0000 2022',
#     'id': 1567817250962382848,
#     'id_str': '1567817250962382848',
#     'text': '#CONCOURS Un iPhone 14 Pro à gagner !\n\nPour participer : RT + follow + like \n\nT.A.S dans 48h ! \n\n#Giveaway #iphone… https://t.co/SdlP5wJ0tc',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'CONCOURS', 'indices': [0, 9]},
#       {'text': 'Giveaway', 'indices': [97, 106]},
#       {'text': 'iphone', 'indices': [107, 114]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/SdlP5wJ0tc',
#        'expanded_url': 'https://twitter.com/i/web/status/1567817250962382848',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1437146065589964803,
#      'id_str': '1437146065589964803',
#      'name': 'HAZ 🚀',
#      'screen_name': '0xHaz666',
#      'location': '',
#      'description': "L'aventador ou la rue | Hold or cry $SOL $ETH $FTT — DM For Business",
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 6681,
#      'friends_count': 32,
#      'listed_count': 5,
#      'created_at': 'Sun Sep 12 20:08:30 +0000 2021',
#      'favourites_count': 8,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 120,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1511723329824169991/tsqi0PPg_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1511723329824169991/tsqi0PPg_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1437146065589964803/1650964936',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 332,
#     'favorite_count': 320,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'fr'},
#    'is_quote_status': False,
#    'retweet_count': 332,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'fr'},
#   {'created_at': 'Wed Sep 14 18:06:46 +0000 2022',
#    'id': 1570111830466379776,
#    'id_str': '1570111830466379776',
#    'text': "RT @stalinkay: It's iPhone 14 Pro Max and Apple Watch Pro launch day, Wednesday, September 7, 2022!\n\nYes or YES?\n\n#Apple #AppleEvent #iPhon…",
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Apple', 'indices': [114, 120]},
#      {'text': 'AppleEvent', 'indices': [121, 132]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'stalinkay',
#       'name': 'Stalin Kay',
#       'id': 39263433,
#       'id_str': '39263433',
#       'indices': [3, 13]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://blackmagic.so" rel="nofollow">BlackMagic.so</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 39263433,
#     'id_str': '39263433',
#     'name': 'Stalin Kay',
#     'screen_name': 'stalinkay',
#     'location': 'Go here👇 or 👉',
#     'description': '🥳 Helps everyday people succeed online #Entrepreneur ≈ Author + Marketer + Musician + Technologist + Futurist https://t.co/6qJZ4TsdPh',
#     'url': 'https://t.co/6qJZ4TsdPh',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/6qJZ4TsdPh',
#         'expanded_url': 'https://www.buymeacoffee.com/stalinkay',
#         'display_url': 'buymeacoffee.com/stalinkay',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/6qJZ4TsdPh',
#         'expanded_url': 'https://www.buymeacoffee.com/stalinkay',
#         'display_url': 'buymeacoffee.com/stalinkay',
#         'indices': [110, 133]}]}},
#     'protected': False,
#     'followers_count': 1200,
#     'friends_count': 5000,
#     'listed_count': 16,
#     'created_at': 'Mon May 11 14:42:36 +0000 2009',
#     'favourites_count': 9532,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 19787,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '131516',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1570107273623502849/c-mV2SLA_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1570107273623502849/c-mV2SLA_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/39263433/1608588931',
#     'profile_link_color': 'E4002B',
#     'profile_sidebar_border_color': 'FFDA21',
#     'profile_sidebar_fill_color': 'FCFCFC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Sep 07 05:57:57 +0000 2022',
#     'id': 1567391701408382976,
#     'id_str': '1567391701408382976',
#     'text': "It's iPhone 14 Pro Max and Apple Watch Pro launch day, Wednesday, September 7, 2022!\n\nYes or YES?\n\n#Apple… https://t.co/qeAAFw5ZI7",
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Apple', 'indices': [99, 105]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/qeAAFw5ZI7',
#        'expanded_url': 'https://twitter.com/i/web/status/1567391701408382976',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [107, 130]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 39263433,
#      'id_str': '39263433',
#      'name': 'Stalin Kay',
#      'screen_name': 'stalinkay',
#      'location': 'Go here👇 or 👉',
#      'description': '🥳 Helps everyday people succeed online #Entrepreneur ≈ Author + Marketer + Musician + Technologist + Futurist https://t.co/6qJZ4TsdPh',
#      'url': 'https://t.co/6qJZ4TsdPh',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/6qJZ4TsdPh',
#          'expanded_url': 'https://www.buymeacoffee.com/stalinkay',
#          'display_url': 'buymeacoffee.com/stalinkay',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/6qJZ4TsdPh',
#          'expanded_url': 'https://www.buymeacoffee.com/stalinkay',
#          'display_url': 'buymeacoffee.com/stalinkay',
#          'indices': [110, 133]}]}},
#      'protected': False,
#      'followers_count': 1200,
#      'friends_count': 5000,
#      'listed_count': 16,
#      'created_at': 'Mon May 11 14:42:36 +0000 2009',
#      'favourites_count': 9532,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 19787,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '131516',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1570107273623502849/c-mV2SLA_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1570107273623502849/c-mV2SLA_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/39263433/1608588931',
#      'profile_link_color': 'E4002B',
#      'profile_sidebar_border_color': 'FFDA21',
#      'profile_sidebar_fill_color': 'FCFCFC',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Sep 14 18:06:31 +0000 2022',
#    'id': 1570111769175113736,
#    'id_str': '1570111769175113736',
#    'text': 'RT @YorubaRepublic: al-Mustapha said Abdusalam Abubakar is a thief! \n\n“I handed over Five hundred million, 23 assorted cars (Benz, limousin…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'YorubaRepublic',
#       'name': 'Yoruba Analyst',
#       'id': 1380156117070839808,
#       'id_str': '1380156117070839808',
#       'indices': [3, 18]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1207856252308602880,
#     'id_str': '1207856252308602880',
#     'name': 'Ọlá👑🇳🇬',
#     'screen_name': 'Larryst51443463',
#     'location': '🌐 ',
#     'description': 'A Geoscientist who loves God and always ready to serve humanity. A passionate teacher.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 130,
#     'friends_count': 836,
#     'listed_count': 0,
#     'created_at': 'Fri Dec 20 02:52:37 +0000 2019',
#     'favourites_count': 6102,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2131,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1554004242297389059/FTLeV2g3_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1554004242297389059/FTLeV2g3_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Sep 08 04:31:21 +0000 2022',
#     'id': 1567732298505650179,
#     'id_str': '1567732298505650179',
#     'text': 'al-Mustapha said Abdusalam Abubakar is a thief! \n\n“I handed over Five hundred million, 23 assorted cars (Benz, limo… https://t.co/wlaxHVncGJ',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/wlaxHVncGJ',
#        'expanded_url': 'https://twitter.com/i/web/status/1567732298505650179',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1380156117070839808,
#      'id_str': '1380156117070839808',
#      'name': 'Yoruba Analyst',
#      'screen_name': 'YorubaRepublic',
#      'location': '',
#      'description': 'Whoever is still campaigning for restructuring under this Fulanised government is short-sighted. He or She is not aware of the reality in Nigeria of today.',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2339,
#      'friends_count': 1534,
#      'listed_count': 5,
#      'created_at': 'Thu Apr 08 13:50:50 +0000 2021',
#      'favourites_count': 159,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 2239,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1439286372741828611/kVQ5StP7_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1439286372741828611/kVQ5StP7_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1380156117070839808/1617891203',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 59,
#     'favorite_count': 61,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 59,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Sep 14 18:06:01 +0000 2022',
#    'id': 1570111644184842241,
#    'id_str': '1570111644184842241',
#    'text': 'RT @SPIDEReGAMES: #CONCOURS !\n🎁 Tentez de gagner un IPhone 14 Pro Max !\n\nPour participer : RT + likes + follow \n@SPIDEReGAMES \n@levraizarkx…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'CONCOURS', 'indices': [18, 27]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SPIDEReGAMES',
#       'name': 'Spider Games',
#       'id': 1100741938184142850,
#       'id_str': '1100741938184142850',
#       'indices': [3, 16]},
#      {'screen_name': 'SPIDEReGAMES',
#       'name': 'Spider Games',
#       'id': 1100741938184142850,
#       'id_str': '1100741938184142850',
#       'indices': [112, 125]},
#      {'screen_name': 'levraizarkx',
#       'name': 'ZarKx \uea00',
#       'id': 1550562701243518977,
#       'id_str': '1550562701243518977',
#       'indices': [127, 139]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1033842582873362433,
#     'id_str': '1033842582873362433',
#     'name': 'Noah',
#     'screen_name': 'noah758983',
#     'location': 'France',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 0,
#     'friends_count': 167,
#     'listed_count': 0,
#     'created_at': 'Sun Aug 26 22:24:14 +0000 2018',
#     'favourites_count': 1040,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 13,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': 'E81C4F',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': True,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Sep 14 16:16:49 +0000 2022',
#     'id': 1570084161456578561,
#     'id_str': '1570084161456578561',
#     'text': '#CONCOURS !\n🎁 Tentez de gagner un IPhone 14 Pro Max !\n\nPour participer : RT + likes + follow \n@SPIDEReGAMES… https://t.co/dAeXQedR5F',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'CONCOURS', 'indices': [0, 9]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'SPIDEReGAMES',
#        'name': 'Spider Games',
#        'id': 1100741938184142850,
#        'id_str': '1100741938184142850',
#        'indices': [94, 107]}],
#      'urls': [{'url': 'https://t.co/dAeXQedR5F',
#        'expanded_url': 'https://twitter.com/i/web/status/1570084161456578561',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [109, 132]}]},
#     'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1100741938184142850,
#      'id_str': '1100741938184142850',
#      'name': 'Spider Games',
#      'screen_name': 'SPIDEReGAMES',
#      'location': 'Sinon Go 200K ',
#      'description': '❤ les gagnants seront affichés sur mon Instagram : spiderr_gamess ❤️',
#      'url': 'https://t.co/nr3LhcimWD',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/nr3LhcimWD',
#          'expanded_url': 'https://www.youtube.com/c/SPIDERGAMESSS/featured',
#          'display_url': 'youtube.com/c/SPIDERGAMESS…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 3048,
#      'friends_count': 28,
#      'listed_count': 0,
#      'created_at': 'Wed Feb 27 12:58:23 +0000 2019',
#      'favourites_count': 450,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 302,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1569599107760590848/G-IRjFJj_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1569599107760590848/G-IRjFJj_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1100741938184142850/1663056576',
#      'profile_link_color': '981CEB',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 37,
#     'favorite_count': 41,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'fr'},
#    'is_quote_status': False,
#    'retweet_count': 37,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'fr'},
#   {'created_at': 'Wed Sep 14 18:05:59 +0000 2022',
#    'id': 1570111634512957440,
#    'id_str': '1570111634512957440',
#    'text': 'RT @levraizarkx: 🎁#CONCOURS !🎁\n\n👉 Tentez de remporter 2 iPhones 14! 😇  \n\n🚨 Pour participer, très simple :\n\n1) #LIKE + #RT ce tweet\n2) Follo…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'CONCOURS', 'indices': [18, 27]},
#      {'text': 'LIKE', 'indices': [110, 115]},
#      {'text': 'RT', 'indices': [118, 121]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'levraizarkx',
#       'name': 'ZarKx \uea00',
#       'id': 1550562701243518977,
#       'id_str': '1550562701243518977',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#    'source': '<a href="http://www.babash.fr" rel="nofollow">lnx621-app-dev2</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1369650653333688320,
#     'id_str': '1369650653333688320',
#     'name': 'lnx62',
#     'screen_name': 'lnx621',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 660,
#     'friends_count': 3096,
#     'listed_count': 5,
#     'created_at': 'Wed Mar 10 14:08:10 +0000 2021',
#     'favourites_count': 5001,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 60784,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1369651463656509448/DeOebPb-_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1369651463656509448/DeOebPb-_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Sep 14 16:21:01 +0000 2022',
#     'id': 1570085219914641409,
#     'id_str': '1570085219914641409',
#     'text': '🎁#CONCOURS !🎁\n\n👉 Tentez de remporter 2 iPhones 14! 😇  \n\n🚨 Pour participer, très simple :\n\n1) #LIKE + #RT ce tweet\n2… https://t.co/yLOCbK6k4x',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'CONCOURS', 'indices': [1, 10]},
#       {'text': 'LIKE', 'indices': [93, 98]},
#       {'text': 'RT', 'indices': [101, 104]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/yLOCbK6k4x',
#        'expanded_url': 'https://twitter.com/i/web/status/1570085219914641409',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1550562701243518977,
#      'id_str': '1550562701243518977',
#      'name': 'ZarKx \uea00',
#      'screen_name': 'levraizarkx',
#      'location': '',
#      'description': '3100 abonnés = ÉNORME SURPRISE 😲',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 3050,
#      'friends_count': 15,
#      'listed_count': 0,
#      'created_at': 'Fri Jul 22 19:25:56 +0000 2022',
#      'favourites_count': 644,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 282,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1568356959287394304/vIp1rCrT_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1568356959287394304/vIp1rCrT_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1550562701243518977/1662760411',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 20,
#     'favorite_count': 23,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'fr'},
#    'is_quote_status': False,
#    'retweet_count': 20,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'fr'},
#   {'created_at': 'Wed Sep 14 18:05:54 +0000 2022',
#    'id': 1570111614782685185,
#    'id_str': '1570111614782685185',
#    'text': 'RT @Golden_Reviewer: I have good news and bad news for you.\nGood news: the #iPhone14 performance is the same as the #iPhone14Pro despite us…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'iPhone14', 'indices': [75, 84]},
#      {'text': 'iPhone14Pro', 'indices': [116, 128]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Golden_Reviewer',
#       'name': 'Golden Reviewer',
#       'id': 130849169,
#       'id_str': '130849169',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1422893115812241409,
#     'id_str': '1422893115812241409',
#     'name': 'Avaz',
#     'screen_name': 'kookaboorra',
#     'location': 'Uzbekistan',
#     'description': "UWED'05 | Senior Product Manager @beeline_uz | Co-founder @mybarakot",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 319,
#     'friends_count': 1107,
#     'listed_count': 9,
#     'created_at': 'Wed Aug 04 12:12:27 +0000 2021',
#     'favourites_count': 5049,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 5336,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1487370016362311684/UgYMZrNP_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1487370016362311684/UgYMZrNP_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Sep 14 14:27:47 +0000 2022',
#     'id': 1570056722307514368,
#     'id_str': '1570056722307514368',
#     'text': 'I have good news and bad news for you.\nGood news: the #iPhone14 performance is the same as the #iPhone14Pro despite… https://t.co/jQmebXpSzs',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'iPhone14', 'indices': [54, 63]},
#       {'text': 'iPhone14Pro', 'indices': [95, 107]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/jQmebXpSzs',
#        'expanded_url': 'https://twitter.com/i/web/status/1570056722307514368',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 130849169,
#      'id_str': '130849169',
#      'name': 'Golden Reviewer',
#      'screen_name': 'Golden_Reviewer',
#      'location': 'Singapore',
#      'description': 'I do in-depth smartphone reviews and tests, follow me on twitter and YouTube! https://t.co/ZYNMBbB5gp',
#      'url': 'https://t.co/ZYNMBbB5gp',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/ZYNMBbB5gp',
#          'expanded_url': 'https://www.youtube.com/c/GoldenReviewer/',
#          'display_url': 'youtube.com/c/GoldenReview…',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/ZYNMBbB5gp',
#          'expanded_url': 'https://www.youtube.com/c/GoldenReviewer/',
#          'display_url': 'youtube.com/c/GoldenReview…',
#          'indices': [78, 101]}]}},
#      'protected': False,
#      'followers_count': 8263,
#      'friends_count': 88,
#      'listed_count': 39,
#      'created_at': 'Thu Apr 08 14:20:00 +0000 2010',
#      'favourites_count': 103,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 1149,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1629052492/usertile61_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1629052492/usertile61_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 29,
#     'favorite_count': 375,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 29,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Sep 14 18:05:43 +0000 2022',
#    'id': 1570111568603643904,
#    'id_str': '1570111568603643904',
#    'text': 'Max is obviously thinking about some Scooby snacks @MKBHD #iphone14pro https://t.co/ek4rXb8MqJ',
# ...
#       'indices': [98, 114]}],
#     'urls': [{'url': 'https://t.co/0SuhqPUEju',
#       'expanded_url': 'https://nl.letsgodigital.org/smartphones/iphone-14-pro/',
#       'display_url': 'nl.letsgodigital.org/smartphones/ip…',
#       'indices': [37, 60]},
#      {'url': 'https://t.co/KDN1dYVOhy',
#       'expanded_url': 'https://www.youtube.com/watch?v=TppeEN7gnsA',
#       'display_url': 'youtube.com/watch?v=TppeEN…',
#       'indices': [115, 138]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1020719828687114241,
#     'id_str': '1020719828687114241',
#     'name': 'Taranjit',
#     'screen_name': 'Taranji47410787',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 52,
#     'friends_count': 384,
#     'listed_count': 0,
#     'created_at': 'Sat Jul 21 17:19:06 +0000 2018',
#     'favourites_count': 49750,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 4149,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Mar 29 05:01:33 +0000 2022',
#     'id': 1508670673996197888,
#     'id_str': '1508670673996197888',
#     'text': 'iPhone 14 Pro 🔥\nhttps://t.co/0SuhqPUEju\n\nYouTube video in collaboration with @TechnizoConcept… https://t.co/MOuA4ifX0B',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'technizoconcept',
#        'name': 'Technizo Concept',
#        'id': 780763566370533381,
#        'id_str': '780763566370533381',
#        'indices': [77, 93]}],
#      'urls': [{'url': 'https://t.co/0SuhqPUEju',
#        'expanded_url': 'https://nl.letsgodigital.org/smartphones/iphone-14-pro/',
#        'display_url': 'nl.letsgodigital.org/smartphones/ip…',
#        'indices': [16, 39]},
#       {'url': 'https://t.co/MOuA4ifX0B',
#        'expanded_url': 'https://twitter.com/i/web/status/1508670673996197888',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [95, 118]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 464864909,
#      'id_str': '464864909',
#      'name': 'LetsGoDigital - Mark Peters',
#      'screen_name': 'letsgodigitalNL',
#      'location': 'Amsterdam',
#      'description': 'Mark Peters - LetsGoDigital\nFounded in 1999 - Amsterdam - The Netherlands\nMember of the international federation of journalists (IFJ)',
#      'url': 'https://t.co/8gCtj5SvPY',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/8gCtj5SvPY',
#          'expanded_url': 'https://nl.letsgodigital.org',
#          'display_url': 'nl.letsgodigital.org',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 20963,
#      'friends_count': 37,
#      'listed_count': 95,
#      'created_at': 'Sun Jan 15 18:20:25 +0000 2012',
#      'favourites_count': 14890,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 4613,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '022330',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1347152007958814727/uwRcjHbg_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1347152007958814727/uwRcjHbg_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/464864909/1646146174',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'A8C7F7',
#      'profile_sidebar_fill_color': 'C0DFEC',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 149,
#     'favorite_count': 898,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 149,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Sep 14 18:03:46 +0000 2022',
#    'id': 1570111075437223939,
#    'id_str': '1570111075437223939',
#    'text': 'RT @El_Ricoy: Soy millonario!! Propietarios de #iPhone14 y #iPhone14Pro, llámenme!! 💵 https://t.co/SftpOiTfHY',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'iPhone14', 'indices': [47, 56]},
#      {'text': 'iPhone14Pro', 'indices': [59, 71]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'El_Ricoy',
#       'name': 'El Ricoy',
#       'id': 23077809,
#       'id_str': '23077809',
#       'indices': [3, 12]}],
#     'urls': [],
#     'media': [{'id': 1570096941924581376,
#       'id_str': '1570096941924581376',
#       'indices': [86, 109],
#       'media_url': 'http://pbs.twimg.com/media/Fcoa2ZZXgAA6Ql2.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Fcoa2ZZXgAA6Ql2.jpg',
#       'url': 'https://t.co/SftpOiTfHY',
#       'display_url': 'pic.twitter.com/SftpOiTfHY',
#       'expanded_url': 'https://twitter.com/El_Ricoy/status/1570096948933173259/photo/1',
#       'type': 'photo',
#       'sizes': {'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 675, 'h': 1200, 'resize': 'fit'},
#        'large': {'w': 1152, 'h': 2048, 'resize': 'fit'}},
#       'source_status_id': 1570096948933173259,
#       'source_status_id_str': '1570096948933173259',
#       'source_user_id': 23077809,
#       'source_user_id_str': '23077809'}]},
#    'extended_entities': {'media': [{'id': 1570096941924581376,
#       'id_str': '1570096941924581376',
#       'indices': [86, 109],
#       'media_url': 'http://pbs.twimg.com/media/Fcoa2ZZXgAA6Ql2.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Fcoa2ZZXgAA6Ql2.jpg',
#       'url': 'https://t.co/SftpOiTfHY',
#       'display_url': 'pic.twitter.com/SftpOiTfHY',
#       'expanded_url': 'https://twitter.com/El_Ricoy/status/1570096948933173259/photo/1',
#       'type': 'photo',
#       'sizes': {'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 675, 'h': 1200, 'resize': 'fit'},
#        'large': {'w': 1152, 'h': 2048, 'resize': 'fit'}},
#       'source_status_id': 1570096948933173259,
#       'source_status_id_str': '1570096948933173259',
#       'source_user_id': 23077809,
#       'source_user_id_str': '23077809'}]},
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 102831167,
#     'id_str': '102831167',
#     'name': '🅳🅾🆁🅺 & 🅁🄾🄻🄻 🏳️\u200d🌈⃤ 🤘🏻🧑🏼',
#     'screen_name': 'DorkBocanegra',
#     'location': '',
#     'description': 'Rockero (córtese el pelo gei), toco el bajo 🎸 *wink* C-ñor de barrio, vulgar, cretino, hostil, visceral, malvibroso, odioso, depresivo y j0t0: Mis cualidades.✨',
#     'url': 'https://t.co/p06NGToL1t',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/p06NGToL1t',
#         'expanded_url': 'http://www.instagram.com/dorkbocanegra',
#         'display_url': 'instagram.com/dorkbocanegra',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3492,
#     'friends_count': 876,
#     'listed_count': 17,
#     'created_at': 'Fri Jan 08 00:16:07 +0000 2010',
#     'favourites_count': 14672,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 55923,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'B2DFDA',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1561927649395707906/EMKN4Xn9_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1561927649395707906/EMKN4Xn9_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/102831167/1661227581',
#     'profile_link_color': '44A667',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'FFFFFF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Sep 14 17:07:38 +0000 2022',
#     'id': 1570096948933173259,
#     'id_str': '1570096948933173259',
#     'text': 'Soy millonario!! Propietarios de #iPhone14 y #iPhone14Pro, llámenme!! 💵 https://t.co/SftpOiTfHY',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'iPhone14', 'indices': [33, 42]},
#       {'text': 'iPhone14Pro', 'indices': [45, 57]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1570096941924581376,
#        'id_str': '1570096941924581376',
#        'indices': [72, 95],
#        'media_url': 'http://pbs.twimg.com/media/Fcoa2ZZXgAA6Ql2.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/Fcoa2ZZXgAA6Ql2.jpg',
#        'url': 'https://t.co/SftpOiTfHY',
#        'display_url': 'pic.twitter.com/SftpOiTfHY',
#        'expanded_url': 'https://twitter.com/El_Ricoy/status/1570096948933173259/photo/1',
#        'type': 'photo',
#        'sizes': {'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 675, 'h': 1200, 'resize': 'fit'},
#         'large': {'w': 1152, 'h': 2048, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1570096941924581376,
#        'id_str': '1570096941924581376',
#        'indices': [72, 95],
#        'media_url': 'http://pbs.twimg.com/media/Fcoa2ZZXgAA6Ql2.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/Fcoa2ZZXgAA6Ql2.jpg',
#        'url': 'https://t.co/SftpOiTfHY',
#        'display_url': 'pic.twitter.com/SftpOiTfHY',
#        'expanded_url': 'https://twitter.com/El_Ricoy/status/1570096948933173259/photo/1',
#        'type': 'photo',
#        'sizes': {'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 675, 'h': 1200, 'resize': 'fit'},
#         'large': {'w': 1152, 'h': 2048, 'resize': 'fit'}}}]},
#     'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 23077809,
#      'id_str': '23077809',
#      'name': 'El Ricoy',
#      'screen_name': 'El_Ricoy',
#      'location': 'En la fila del Oxxo',
#      'description': 'Nacido en chilangolandia, calado en la ciudad del camote, expatriado al Bajío #NeuroticToTheBone | #YaMeAndaDelRealEstate',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1286,
#      'friends_count': 1830,
#      'listed_count': 11,
#      'created_at': 'Fri Mar 06 15:41:08 +0000 2009',
#      'favourites_count': 2714,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 23653,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1430401808783052800/JP6-grGR_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1430401808783052800/JP6-grGR_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/23077809/1556422072',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 3,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'es'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'es'}],
#  'search_metadata': {'completed_in': 0.121,
#   'max_id': 1570111920660938752,
#   'max_id_str': '1570111920660938752',
#   'next_results': '?max_id=1570111075437223938&q=%23iPhone14Pro&include_entities=1',
#   'query': '%23iPhone14Pro',
#   'refresh_url': '?since_id=1570111920660938752&q=%23iPhone14Pro&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %% [markdown]
# ### Loading credentials and Tweepy authentication

# %%
# read configs

config = configparser.ConfigParser()
config.read('../../../config_files/config.ini')

api_key = config['twitter']['api_key']
api_key_secret = config['twitter']['api_key_secret']

access_token = config['twitter']['access_token']
access_token_secret = config['twitter']['access_token_secret']

# %%
# authentication

auth = tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %% [markdown]
# ### Data gathering from Twitter API

# %%
# gathering data from API

keywords = '#iPhone14Pro'
limit = 1000

tweets = tweepy.Cursor(api.search_tweets, q=keywords, lang='en', count=100,
                       tweet_mode='extended').items(limit)

# creating DataFrame

columns = ['User', 'DateTime', 'Tweet']
data = []

for tweet in tweets:
    data.append([tweet.user.screen_name, tweet.created_at, tweet.full_text])
    
df = pd.DataFrame(data, columns=columns)

df.head()
# Out:
#             User                  DateTime  \
# 0        Navilll 2022-09-14 17:49:13+00:00
# 1    DimitarCruz 2022-09-14 17:47:40+00:00
# 2  NazgulEnTongs 2022-09-14 17:43:49+00:00
# 3  ChronicallyTG 2022-09-14 17:43:38+00:00
# 4   andrewjclare 2022-09-14 17:43:14+00:00
#
#                                                Tweet
# 0  RT @insanetweet: iPhone 8 while upgrading to i...
# 1  @ijustine @armaniblanco Here’s LG V10 with #dy...
# 2  RT @ksmolka: Who has an iPhone 14 Pro right no...
# 3  @comeclosefitymu 😂no😂 it’s gonna flood your ti...
# 4  New #iPhone14Pro cases from @TotalleeCase.  Th...

# %%
#df.to_csv('../data/raw/iPhone14Prox10k_RAW_2.csv)

# %%
print(tweets)
# Out:
# <tweepy.cursor.ItemIterator object at 0x16547e310>

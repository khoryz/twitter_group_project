# %% [markdown]
# # Twitter API Scraping

# %% [markdown]
# ### Packages to load

# %%
import tweepy
import configparser
import pandas as pd
import numpy as np
import json
from twython import Twython

# %% [markdown]
# ### Other stuff to load

# %%
# nothing

# %% [markdown]
# ### Loading credentials and Twython authentication

# %%
with open("../../../config_files/credentials.json") as infile:
    credentials = json.load(infile)

twitter_client = Twython(credentials["api_key"],
                         credentials["api_secret"],
                         credentials["access_token"],
                         credentials["access_token_secret"])

# %% [markdown]
# ### Data gathering test from Twython

# %%
# trying to gather from Twython

keywords = '#iPhone14Pro'

twitter_client.search(q=keywords)
# Out:
# {'statuses': [{'created_at': 'Thu Sep 15 08:37:39 +0000 2022',
#    'id': 1570330997606219776,
#    'id_str': '1570330997606219776',
#    'text': '出荷されたー！\n明日だぁー！\n#iPhone14Pro #ゴールド https://t.co/W2kUkToG3i',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'iPhone14Pro', 'indices': [15, 27]},
#      {'text': 'ゴールド', 'indices': [28, 33]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1570330989448286208,
#       'id_str': '1570330989448286208',
#       'indices': [34, 57],
#       'media_url': 'http://pbs.twimg.com/media/FcrvtwXaUAAshUn.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/FcrvtwXaUAAshUn.jpg',
#       'url': 'https://t.co/W2kUkToG3i',
#       'display_url': 'pic.twitter.com/W2kUkToG3i',
#       'expanded_url': 'https://twitter.com/RN_666777/status/1570330997606219776/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 554, 'h': 1200, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 314, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 946, 'h': 2048, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1570330989448286208,
#       'id_str': '1570330989448286208',
#       'indices': [34, 57],
#       'media_url': 'http://pbs.twimg.com/media/FcrvtwXaUAAshUn.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/FcrvtwXaUAAshUn.jpg',
#       'url': 'https://t.co/W2kUkToG3i',
#       'display_url': 'pic.twitter.com/W2kUkToG3i',
#       'expanded_url': 'https://twitter.com/RN_666777/status/1570330997606219776/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 554, 'h': 1200, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 314, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 946, 'h': 2048, 'resize': 'fit'}}}]},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 924964693088788480,
#     'id_str': '924964693088788480',
#     'name': '꒰ঌりなぴ໒꒱🧸ིྀ👑🌈ライトワーカースピチューラー🔮🌈@幸せ🌻の投資コンサルタント',
#     'screen_name': 'RN_666777',
#     'location': '東京港区と地方に家あり(実家は別にあります)',
#     'description': '投資コンサルタント💗皆を幸せにする💗お問い合わせは下記かᴅᴍで。詐欺は潰す😡スピリチュアルと美容とコリラックマ𝕃𝕠𝕧𝕖💗ᴠ𝟛シリーズ.ᴠᴏsシリーズ.イヤココ💗美容代は月に約60万円🌹ダイエット中🧘\u200d♀️ライトワーカースピチューラー🔮🌈カードリーディング🔮ペンデュラム🔮',
#     'url': 'https://t.co/oqRCcRDt1l',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/oqRCcRDt1l',
#         'expanded_url': 'https://lit.link/rinapisan77',
#         'display_url': 'lit.link/rinapisan77',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 492,
#     'friends_count': 385,
#     'listed_count': 12,
#     'created_at': 'Mon Oct 30 11:42:22 +0000 2017',
#     'favourites_count': 9279,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 8247,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1567027775835611138/nsBLN-k1_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1567027775835611138/nsBLN-k1_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/924964693088788480/1633318082',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'ja'},
#   {'created_at': 'Thu Sep 15 08:37:28 +0000 2022',
#    'id': 1570330948407029761,
#    'id_str': '1570330948407029761',
#    'text': "RT @iam_abdulsalim: @WS_MobileTrans 'Nothing Changed After Transfer'❤️❤️❤️\n\nSome memories stills in our heart's. That has no words to expre…",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'iam_abdulsalim',
#       'name': 'ABDUL SALIM',
#       'id': 1416491989340762112,
#       'id_str': '1416491989340762112',
#       'indices': [3, 18]},
#      {'screen_name': 'WS_MobileTrans',
#       'name': 'Wondershare MobileTrans Phone Transfer Solution',
#       'id': 718385978679894018,
#       'id_str': '718385978679894018',
#       'indices': [20, 35]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1416491989340762112,
#     'id_str': '1416491989340762112',
#     'name': 'ABDUL SALIM',
#     'screen_name': 'iam_abdulsalim',
#     'location': '',
#     'description': 'The purpose of our lives is to be happy \n#farmer🌴 #SocialWorker 🫂#ProudIndian 🇮🇳#Familyman👨\u200d👩\u200d👦\u200d👦 #AyurvedaRepresentative🌿 #EcoGuradian #commonman😊🙏',
#     'url': 'https://t.co/LHigKpJoFY',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/LHigKpJoFY',
#         'expanded_url': 'https://instagram.com/iam_abdulsalim?igshid=YmMyMTA2M2Y=',
#         'display_url': 'instagram.com/iam_abdulsalim…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 40,
#     'friends_count': 398,
#     'listed_count': 0,
#     'created_at': 'Sat Jul 17 20:16:31 +0000 2021',
#     'favourites_count': 2780,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1627,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1570108338704379905/lX2Hr2XK_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1570108338704379905/lX2Hr2XK_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1416491989340762112/1659467217',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Sep 15 08:35:19 +0000 2022',
#     'id': 1570330410634317824,
#     'id_str': '1570330410634317824',
#     'text': "@WS_MobileTrans 'Nothing Changed After Transfer'❤️❤️❤️\n\nSome memories stills in our heart's. That has no words to e… https://t.co/cipJIbX5O7",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'WS_MobileTrans',
#        'name': 'Wondershare MobileTrans Phone Transfer Solution',
#        'id': 718385978679894018,
#        'id_str': '718385978679894018',
#        'indices': [0, 15]}],
#      'urls': [{'url': 'https://t.co/cipJIbX5O7',
#        'expanded_url': 'https://twitter.com/i/web/status/1570330410634317824',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': 1567843703137640449,
#     'in_reply_to_status_id_str': '1567843703137640449',
#     'in_reply_to_user_id': 718385978679894018,
#     'in_reply_to_user_id_str': '718385978679894018',
#     'in_reply_to_screen_name': 'WS_MobileTrans',
#     'user': {'id': 1416491989340762112,
#      'id_str': '1416491989340762112',
#      'name': 'ABDUL SALIM',
#      'screen_name': 'iam_abdulsalim',
#      'location': '',
#      'description': 'The purpose of our lives is to be happy \n#farmer🌴 #SocialWorker 🫂#ProudIndian 🇮🇳#Familyman👨\u200d👩\u200d👦\u200d👦 #AyurvedaRepresentative🌿 #EcoGuradian #commonman😊🙏',
#      'url': 'https://t.co/LHigKpJoFY',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/LHigKpJoFY',
#          'expanded_url': 'https://instagram.com/iam_abdulsalim?igshid=YmMyMTA2M2Y=',
#          'display_url': 'instagram.com/iam_abdulsalim…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 40,
#      'friends_count': 398,
#      'listed_count': 0,
#      'created_at': 'Sat Jul 17 20:16:31 +0000 2021',
#      'favourites_count': 2780,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 1627,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1570108338704379905/lX2Hr2XK_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1570108338704379905/lX2Hr2XK_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1416491989340762112/1659467217',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Sep 15 08:37:25 +0000 2022',
#    'id': 1570330938206461952,
#    'id_str': '1570330938206461952',
#    'text': "RT @bobbydefi: #Defiwars project is full of potential and #utilities you wouldn't want to skip at all.\nGet in today and wait for the #Launc…",
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Defiwars', 'indices': [15, 24]},
#      {'text': 'utilities', 'indices': [58, 68]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'bobbydefi',
#       'name': 'bobbyDefi',
#       'id': 1559535489283227648,
#       'id_str': '1559535489283227648',
#       'indices': [3, 13]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1501972811753136130,
#     'id_str': '1501972811753136130',
#     'name': 'Steve Arnold',
#     'screen_name': 'Steve_Arnold__',
#     'location': '',
#     'description': 'Be nice!!!',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1546,
#     'friends_count': 19,
#     'listed_count': 0,
#     'created_at': 'Thu Mar 10 17:26:51 +0000 2022',
#     'favourites_count': 1096,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1076,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1502024983995994118/t7zy__jw_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1502024983995994118/t7zy__jw_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Sep 13 21:54:52 +0000 2022',
#     'id': 1569806848043417601,
#     'id_str': '1569806848043417601',
#     'text': "#Defiwars project is full of potential and #utilities you wouldn't want to skip at all.\nGet in today and wait for t… https://t.co/MEjRBLb7bm",
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Defiwars', 'indices': [0, 9]},
#       {'text': 'utilities', 'indices': [43, 53]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/MEjRBLb7bm',
#        'expanded_url': 'https://twitter.com/i/web/status/1569806848043417601',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1559535489283227648,
#      'id_str': '1559535489283227648',
#      'name': 'bobbyDefi',
#      'screen_name': 'bobbydefi',
#      'location': 'United Kingdom',
#      'description': 'ï äm ä jøvïäl përsøn',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 572,
#      'friends_count': 31,
#      'listed_count': 0,
#      'created_at': 'Tue Aug 16 13:40:22 +0000 2022',
#      'favourites_count': 373,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 377,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1559536860690530305/Hy-N5XdP_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1559536860690530305/Hy-N5XdP_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1559535489283227648/1660657609',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Sep 15 08:37:00 +0000 2022',
#    'id': 1570330833898115072,
#    'id_str': '1570330833898115072',
#    'text': 'RT @7Alsabe: وش الفرق بين #iPhone14 و #iPhone14Pro إذا كنت مو عارف وش تشتري الفيديو هذا بيساعدك https://t.co/lJE5GCOVNZ',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'iPhone14', 'indices': [26, 35]},
#      {'text': 'iPhone14Pro', 'indices': [38, 50]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': '7Alsabe',
#       'name': 'عبدالله السبع',
#       'id': 312576919,
#       'id_str': '312576919',
#       'indices': [3, 11]}],
#     'urls': [],
#     'media': [{'id': 1570086992473358338,
#       'id_str': '1570086992473358338',
#       'indices': [96, 119],
#       'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1570086992473358338/img/357vYrJBJx8Xf9MR.jpg',
#       'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1570086992473358338/img/357vYrJBJx8Xf9MR.jpg',
#       'url': 'https://t.co/lJE5GCOVNZ',
#       'display_url': 'pic.twitter.com/lJE5GCOVNZ',
#       'expanded_url': 'https://twitter.com/7Alsabe/status/1570087966277500932/video/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 680, 'h': 380, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 670, 'resize': 'fit'},
#        'large': {'w': 1920, 'h': 1072, 'resize': 'fit'}},
#       'source_status_id': 1570087966277500932,
#       'source_status_id_str': '1570087966277500932',
#       'source_user_id': 312576919,
#       'source_user_id_str': '312576919'}]},
#    'extended_entities': {'media': [{'id': 1570086992473358338,
#       'id_str': '1570086992473358338',
#       'indices': [96, 119],
#       'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1570086992473358338/img/357vYrJBJx8Xf9MR.jpg',
#       'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1570086992473358338/img/357vYrJBJx8Xf9MR.jpg',
#       'url': 'https://t.co/lJE5GCOVNZ',
#       'display_url': 'pic.twitter.com/lJE5GCOVNZ',
#       'expanded_url': 'https://twitter.com/7Alsabe/status/1570087966277500932/video/1',
#       'type': 'video',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 680, 'h': 380, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 670, 'resize': 'fit'},
#        'large': {'w': 1920, 'h': 1072, 'resize': 'fit'}},
#       'source_status_id': 1570087966277500932,
#       'source_status_id_str': '1570087966277500932',
#       'source_user_id': 312576919,
#       'source_user_id_str': '312576919',
#       'video_info': {'aspect_ratio': [120, 67],
#        'duration_millis': 151766,
#        'variants': [{'bitrate': 2176000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/amplify_video/1570086992473358338/vid/1288x720/kP5OuwWnFsT7jUVK.mp4?tag=14'},
#         {'bitrate': 288000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/amplify_video/1570086992473358338/vid/482x270/k08BNKlpg35CzQ5Q.mp4?tag=14'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/amplify_video/1570086992473358338/pl/BwksUd9_ZYPdiw51.m3u8?tag=14&container=fmp4'},
#         {'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/amplify_video/1570086992473358338/vid/644x360/3ZJZdVGDPFOIN7Lk.mp4?tag=14'}]},
#       'additional_media_info': {'title': '',
#        'description': '',
#        'embeddable': True,
#        'monetizable': False,
#        'source_user': {'id': 312576919,
#         'id_str': '312576919',
#         'name': 'عبدالله السبع',
#         'screen_name': '7Alsabe',
#         'location': 'الرياض',
#         'description': 'المحرر التقني في صحيفة اندبندنت العربية alsabe3.7@gmail.com',
#         'url': 'https://t.co/LQJzUlYoGC',
#         'entities': {'url': {'urls': [{'url': 'https://t.co/LQJzUlYoGC',
#             'expanded_url': 'http://7Alsabe.com',
#             'display_url': '7Alsabe.com',
#             'indices': [0, 23]}]},
#          'description': {'urls': []}},
#         'protected': False,
#         'followers_count': 1386687,
#         'friends_count': 495,
#         'listed_count': 2800,
#         'created_at': 'Tue Jun 07 10:29:38 +0000 2011',
#         'favourites_count': 501,
#         'utc_offset': None,
#         'time_zone': None,
#         'geo_enabled': True,
#         'verified': True,
#         'statuses_count': 156987,
#         'lang': None,
#         'contributors_enabled': False,
#         'is_translator': False,
#         'is_translation_enabled': False,
#         'profile_background_color': '000000',
#         'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme7/bg.gif',
#         'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme7/bg.gif',
#         'profile_background_tile': False,
#         'profile_image_url': 'http://pbs.twimg.com/profile_images/1487173309213167619/JU0SZ2fe_normal.jpg',
#         'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1487173309213167619/JU0SZ2fe_normal.jpg',
#         'profile_banner_url': 'https://pbs.twimg.com/profile_banners/312576919/1646679154',
#         'profile_link_color': '91D2FA',
#         'profile_sidebar_border_color': '000000',
#         'profile_sidebar_fill_color': '000000',
#         'profile_text_color': '000000',
#         'profile_use_background_image': False,
#         'has_extended_profile': True,
#         'default_profile': False,
#         'default_profile_image': False,
#         'following': False,
#         'follow_request_sent': False,
#         'notifications': False,
#         'translator_type': 'none',
#         'withheld_in_countries': []}}}]},
#    'metadata': {'iso_language_code': 'ar', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2411708053,
#     'id_str': '2411708053',
#     'name': '♥︎\xa0𝙵𝙰𝚃𝙼𝙰 ♥︎',
#     'screen_name': '2022Girls',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1494,
#     'friends_count': 863,
#     'listed_count': 0,
#     'created_at': 'Tue Mar 25 23:41:45 +0000 2014',
#     'favourites_count': 20502,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 9292,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1561628442440900608/6-SDNf6s_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1561628442440900608/6-SDNf6s_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2411708053/1658375696',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Sep 14 16:31:56 +0000 2022',
#     'id': 1570087966277500932,
#     'id_str': '1570087966277500932',
#     'text': 'وش الفرق بين #iPhone14 و #iPhone14Pro إذا كنت مو عارف وش تشتري الفيديو هذا بيساعدك https://t.co/lJE5GCOVNZ',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'iPhone14', 'indices': [13, 22]},
#       {'text': 'iPhone14Pro', 'indices': [25, 37]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1570086992473358338,
#        'id_str': '1570086992473358338',
#        'indices': [83, 106],
#        'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1570086992473358338/img/357vYrJBJx8Xf9MR.jpg',
#        'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1570086992473358338/img/357vYrJBJx8Xf9MR.jpg',
#        'url': 'https://t.co/lJE5GCOVNZ',
#        'display_url': 'pic.twitter.com/lJE5GCOVNZ',
#        'expanded_url': 'https://twitter.com/7Alsabe/status/1570087966277500932/video/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 680, 'h': 380, 'resize': 'fit'},
#         'medium': {'w': 1200, 'h': 670, 'resize': 'fit'},
#         'large': {'w': 1920, 'h': 1072, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1570086992473358338,
#        'id_str': '1570086992473358338',
#        'indices': [83, 106],
#        'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1570086992473358338/img/357vYrJBJx8Xf9MR.jpg',
#        'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1570086992473358338/img/357vYrJBJx8Xf9MR.jpg',
#        'url': 'https://t.co/lJE5GCOVNZ',
#        'display_url': 'pic.twitter.com/lJE5GCOVNZ',
#        'expanded_url': 'https://twitter.com/7Alsabe/status/1570087966277500932/video/1',
#        'type': 'video',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 680, 'h': 380, 'resize': 'fit'},
#         'medium': {'w': 1200, 'h': 670, 'resize': 'fit'},
#         'large': {'w': 1920, 'h': 1072, 'resize': 'fit'}},
#        'video_info': {'aspect_ratio': [120, 67],
#         'duration_millis': 151766,
#         'variants': [{'bitrate': 2176000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/amplify_video/1570086992473358338/vid/1288x720/kP5OuwWnFsT7jUVK.mp4?tag=14'},
#          {'bitrate': 288000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/amplify_video/1570086992473358338/vid/482x270/k08BNKlpg35CzQ5Q.mp4?tag=14'},
#          {'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/amplify_video/1570086992473358338/pl/BwksUd9_ZYPdiw51.m3u8?tag=14&container=fmp4'},
#          {'bitrate': 832000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/amplify_video/1570086992473358338/vid/644x360/3ZJZdVGDPFOIN7Lk.mp4?tag=14'}]},
#        'additional_media_info': {'title': '',
#         'description': '',
#         'embeddable': True,
#         'monetizable': False}}]},
#     'metadata': {'iso_language_code': 'ar', 'result_type': 'recent'},
#     'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 312576919,
#      'id_str': '312576919',
#      'name': 'عبدالله السبع',
#      'screen_name': '7Alsabe',
#      'location': 'الرياض',
#      'description': 'المحرر التقني في صحيفة اندبندنت العربية alsabe3.7@gmail.com',
#      'url': 'https://t.co/LQJzUlYoGC',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/LQJzUlYoGC',
#          'expanded_url': 'http://7Alsabe.com',
#          'display_url': '7Alsabe.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1386687,
#      'friends_count': 495,
#      'listed_count': 2800,
#      'created_at': 'Tue Jun 07 10:29:38 +0000 2011',
#      'favourites_count': 501,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 156987,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme7/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme7/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1487173309213167619/JU0SZ2fe_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1487173309213167619/JU0SZ2fe_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/312576919/1646679154',
#      'profile_link_color': '91D2FA',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 69,
#     'favorite_count': 448,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'ar'},
#    'is_quote_status': False,
#    'retweet_count': 69,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'ar'},
#   {'created_at': 'Thu Sep 15 08:36:57 +0000 2022',
#    'id': 1570330821734682626,
#    'id_str': '1570330821734682626',
#    'text': 'RT @SPIDEReGAMES: #CONCOURS !\n🎁 Tentez de gagner un IPhone 14 Pro Max !\n\nPour participer : RT + likes + follow \n@SPIDEReGAMES \n@levraizarkx…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'CONCOURS', 'indices': [18, 27]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SPIDEReGAMES',
#       'name': 'Spider Games',
#       'id': 1100741938184142850,
#       'id_str': '1100741938184142850',
#       'indices': [3, 16]},
#      {'screen_name': 'SPIDEReGAMES',
#       'name': 'Spider Games',
#       'id': 1100741938184142850,
#       'id_str': '1100741938184142850',
#       'indices': [112, 125]},
#      {'screen_name': 'levraizarkx',
#       'name': 'ZarKx \uea00',
#       'id': 1550562701243518977,
#       'id_str': '1550562701243518977',
#       'indices': [127, 139]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1518173333833068545,
#     'id_str': '1518173333833068545',
#     'name': 'FLORENT MUNIER',
#     'screen_name': 'FMunier2022',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 54,
#     'friends_count': 161,
#     'listed_count': 0,
#     'created_at': 'Sun Apr 24 10:22:28 +0000 2022',
#     'favourites_count': 398,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 108,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1518173521062600704/ZdrkdCVz_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1518173521062600704/ZdrkdCVz_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Sep 14 16:16:49 +0000 2022',
#     'id': 1570084161456578561,
#     'id_str': '1570084161456578561',
#     'text': '#CONCOURS !\n🎁 Tentez de gagner un IPhone 14 Pro Max !\n\nPour participer : RT + likes + follow \n@SPIDEReGAMES… https://t.co/dAeXQedR5F',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'CONCOURS', 'indices': [0, 9]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'SPIDEReGAMES',
#        'name': 'Spider Games',
#        'id': 1100741938184142850,
#        'id_str': '1100741938184142850',
#        'indices': [94, 107]}],
#      'urls': [{'url': 'https://t.co/dAeXQedR5F',
#        'expanded_url': 'https://twitter.com/i/web/status/1570084161456578561',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [109, 132]}]},
#     'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1100741938184142850,
#      'id_str': '1100741938184142850',
#      'name': 'Spider Games',
#      'screen_name': 'SPIDEReGAMES',
#      'location': 'Sinon Go 200K ',
#      'description': '❤ les gagnants seront affichés sur mon Instagram : spiderr_gamess ❤️',
#      'url': 'https://t.co/nr3LhcimWD',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/nr3LhcimWD',
#          'expanded_url': 'https://www.youtube.com/c/SPIDERGAMESSS/featured',
#          'display_url': 'youtube.com/c/SPIDERGAMESS…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 3206,
#      'friends_count': 30,
#      'listed_count': 0,
#      'created_at': 'Wed Feb 27 12:58:23 +0000 2019',
#      'favourites_count': 451,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 300,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1569599107760590848/G-IRjFJj_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1569599107760590848/G-IRjFJj_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1100741938184142850/1663056576',
#      'profile_link_color': '981CEB',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 291,
#     'favorite_count': 284,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'fr'},
#    'is_quote_status': False,
#    'retweet_count': 291,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'fr'},
#   {'created_at': 'Thu Sep 15 08:36:55 +0000 2022',
#    'id': 1570330812612218880,
#    'id_str': '1570330812612218880',
#    'text': 'RT @SPIDEReGAMES: #CONCOURS !\n🎁 Tentez de gagner un IPhone 14 Pro Max !\n\nPour participer : RT + likes + follow \n@SPIDEReGAMES \n@levraizarkx…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'CONCOURS', 'indices': [18, 27]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SPIDEReGAMES',
#       'name': 'Spider Games',
#       'id': 1100741938184142850,
#       'id_str': '1100741938184142850',
#       'indices': [3, 16]},
#      {'screen_name': 'SPIDEReGAMES',
#       'name': 'Spider Games',
#       'id': 1100741938184142850,
#       'id_str': '1100741938184142850',
#       'indices': [112, 125]},
#      {'screen_name': 'levraizarkx',
#       'name': 'ZarKx \uea00',
#       'id': 1550562701243518977,
#       'id_str': '1550562701243518977',
#       'indices': [127, 139]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1516188952549548032,
#     'id_str': '1516188952549548032',
#     'name': 'jose maria barroso romero',
#     'screen_name': 'josemar94862482',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 0,
#     'friends_count': 45,
#     'listed_count': 0,
#     'created_at': 'Mon Apr 18 22:56:48 +0000 2022',
#     'favourites_count': 37,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 35,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1568913513485160448/1QnZQ2lj_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1568913513485160448/1QnZQ2lj_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Sep 14 16:16:49 +0000 2022',
#     'id': 1570084161456578561,
#     'id_str': '1570084161456578561',
#     'text': '#CONCOURS !\n🎁 Tentez de gagner un IPhone 14 Pro Max !\n\nPour participer : RT + likes + follow \n@SPIDEReGAMES… https://t.co/dAeXQedR5F',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'CONCOURS', 'indices': [0, 9]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'SPIDEReGAMES',
#        'name': 'Spider Games',
#        'id': 1100741938184142850,
#        'id_str': '1100741938184142850',
#        'indices': [94, 107]}],
#      'urls': [{'url': 'https://t.co/dAeXQedR5F',
#        'expanded_url': 'https://twitter.com/i/web/status/1570084161456578561',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [109, 132]}]},
#     'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1100741938184142850,
#      'id_str': '1100741938184142850',
#      'name': 'Spider Games',
#      'screen_name': 'SPIDEReGAMES',
#      'location': 'Sinon Go 200K ',
#      'description': '❤ les gagnants seront affichés sur mon Instagram : spiderr_gamess ❤️',
#      'url': 'https://t.co/nr3LhcimWD',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/nr3LhcimWD',
#          'expanded_url': 'https://www.youtube.com/c/SPIDERGAMESSS/featured',
#          'display_url': 'youtube.com/c/SPIDERGAMESS…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 3206,
#      'friends_count': 30,
#      'listed_count': 0,
#      'created_at': 'Wed Feb 27 12:58:23 +0000 2019',
#      'favourites_count': 451,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 300,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1569599107760590848/G-IRjFJj_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1569599107760590848/G-IRjFJj_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1100741938184142850/1663056576',
#      'profile_link_color': '981CEB',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 291,
#     'favorite_count': 284,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'fr'},
#    'is_quote_status': False,
#    'retweet_count': 291,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'fr'},
#   {'created_at': 'Thu Sep 15 08:36:31 +0000 2022',
#    'id': 1570330710694834176,
#    'id_str': '1570330710694834176',
#    'text': "RT @Setec_FR: 🎁 #CONCOURS #GIVEAWAY 🎁\n\nL'équipe #SETEC vous offre la chance de remporter un #iPhone14Pro ! \n\nPour participer:\n\n🔁 Retweet ce…",
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'CONCOURS', 'indices': [16, 25]},
#      {'text': 'GIVEAWAY', 'indices': [26, 35]},
#      {'text': 'SETEC', 'indices': [48, 54]},
#      {'text': 'iPhone14Pro', 'indices': [92, 104]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Setec_FR',
#       'name': 'Setec 🇫🇷',
#       'id': 1079167257966772224,
#       'id_str': '1079167257966772224',
#       'indices': [3, 12]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2979529545,
#     'id_str': '2979529545',
#     'name': 'Vanouche67',
#     'screen_name': 'Vanessa67V',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1029,
#     'friends_count': 4865,
#     'listed_count': 261,
#     'created_at': 'Thu Jan 15 10:34:13 +0000 2015',
#     'favourites_count': 85616,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 114608,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1500510294493351939/Opzq8wo4_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1500510294493351939/Opzq8wo4_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2979529545/1590697253',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Sep 09 06:58:54 +0000 2022',
#     'id': 1568131818238394368,
#     'id_str': '1568131818238394368',
#     'text': "🎁 #CONCOURS #GIVEAWAY 🎁\n\nL'équipe #SETEC vous offre la chance de remporter un #iPhone14Pro ! \n\nPour participer:\n\n🔁… https://t.co/fGDxNdzY80",
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'CONCOURS', 'indices': [2, 11]},
#       {'text': 'GIVEAWAY', 'indices': [12, 21]},
#       {'text': 'SETEC', 'indices': [34, 40]},
#       {'text': 'iPhone14Pro', 'indices': [78, 90]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/fGDxNdzY80',
#        'expanded_url': 'https://twitter.com/i/web/status/1568131818238394368',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1079167257966772224,
#      'id_str': '1079167257966772224',
#      'name': 'Setec 🇫🇷',
#      'screen_name': 'Setec_FR',
#      'location': 'Paris 17 🇫🇷',
#      'description': '🇫🇷 Digital Agency since 2012\n\n⚡ Make your power on the net with us',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1300,
#      'friends_count': 15,
#      'listed_count': 0,
# ...
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'iPhone14Pro', 'indices': [40, 52]},
#       {'text': '5G', 'indices': [107, 110]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/qjpwxiK8ry',
#        'expanded_url': 'https://twitter.com/i/web/status/1570199598756696064',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://www.everyonesocial.com" rel="nofollow">EveryoneSocial</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 789851059418116098,
#      'id_str': '789851059418116098',
#      'name': 'Ms. Marie Sifuentes',
#      'screen_name': 'MsMarieDotCom',
#      'location': 'Dallas, TX',
#      'description': 'Airbnb Superhost, Cuban Coffee Maker, Fashionista, Inclusionist, Innovator, Latina, Mom, Notary Public, Ordained Minister, Visionary Leader & Women Advocate',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 8095,
#      'friends_count': 4089,
#      'listed_count': 9,
#      'created_at': 'Sat Oct 22 15:29:02 +0000 2016',
#      'favourites_count': 41635,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 21039,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1569135020274483201/y7usqXeA_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1569135020274483201/y7usqXeA_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/789851059418116098/1662952428',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Sep 15 08:35:23 +0000 2022',
#    'id': 1570330425889009665,
#    'id_str': '1570330425889009665',
#    'text': 'RT @moonluvsaturday: -Pls rt-\n✨ มูก่อนเลย ถ้าวันที่16นี้ walk in เข้าไปซื้อ iPhone 14 pro สีเสปซแบล๊ค 128-256 ได้1 เครื่อง แจก 100/คน 2คน…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'moonluvsaturday',
#       'name': '\U0001faf6🏻ft.เอาไว้ฟอลกลับ',
#       'id': 1257188854215278592,
#       'id_str': '1257188854215278592',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'th', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1547913949835714566,
#     'id_str': '1547913949835714566',
#     'name': 'PTT',
#     'screen_name': 'kingdomofPTT',
#     'location': '',
#     'description': '𝟏𝟗𝟗𝟗’𝐬 ข้าเจ้าเป็นสาวเจียงใหม่',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4,
#     'friends_count': 67,
#     'listed_count': 0,
#     'created_at': 'Fri Jul 15 12:00:40 +0000 2022',
#     'favourites_count': 167,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1851,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1547915586620903428/TUZcGGQF_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1547915586620903428/TUZcGGQF_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Sep 14 17:07:16 +0000 2022',
#     'id': 1570096859376668673,
#     'id_str': '1570096859376668673',
#     'text': '-Pls rt-\n✨ มูก่อนเลย ถ้าวันที่16นี้ walk in เข้าไปซื้อ iPhone 14 pro สีเสปซแบล๊ค 128-256 ได้1 เครื่อง แจก 100/คน 2ค… https://t.co/kns7aIAF57',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/kns7aIAF57',
#        'expanded_url': 'https://twitter.com/i/web/status/1570096859376668673',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'th', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1257188854215278592,
#      'id_str': '1257188854215278592',
#      'name': '\U0001faf6🏻ft.เอาไว้ฟอลกลับ',
#      'screen_name': 'moonluvsaturday',
#      'location': '',
#      'description': 'มอป.',
#      'url': 'https://t.co/nf9Swezp8E',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/nf9Swezp8E',
#          'expanded_url': 'https://youtu.be/EFHeeRIDAsg',
#          'display_url': 'youtu.be/EFHeeRIDAsg',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 53,
#      'friends_count': 143,
#      'listed_count': 0,
#      'created_at': 'Mon May 04 06:02:46 +0000 2020',
#      'favourites_count': 16,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 52,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1551614828766445568/me60ONnT_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1551614828766445568/me60ONnT_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1257188854215278592/1658768789',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 49,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'th'},
#    'is_quote_status': False,
#    'retweet_count': 49,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'th'},
#   {'created_at': 'Thu Sep 15 08:35:19 +0000 2022',
#    'id': 1570330410634317824,
#    'id_str': '1570330410634317824',
#    'text': "@WS_MobileTrans 'Nothing Changed After Transfer'❤️❤️❤️\n\nSome memories stills in our heart's. That has no words to e… https://t.co/cipJIbX5O7",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'WS_MobileTrans',
#       'name': 'Wondershare MobileTrans Phone Transfer Solution',
#       'id': 718385978679894018,
#       'id_str': '718385978679894018',
#       'indices': [0, 15]}],
#     'urls': [{'url': 'https://t.co/cipJIbX5O7',
#       'expanded_url': 'https://twitter.com/i/web/status/1570330410634317824',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1567843703137640449,
#    'in_reply_to_status_id_str': '1567843703137640449',
#    'in_reply_to_user_id': 718385978679894018,
#    'in_reply_to_user_id_str': '718385978679894018',
#    'in_reply_to_screen_name': 'WS_MobileTrans',
#    'user': {'id': 1416491989340762112,
#     'id_str': '1416491989340762112',
#     'name': 'ABDUL SALIM',
#     'screen_name': 'iam_abdulsalim',
#     'location': '',
#     'description': 'The purpose of our lives is to be happy \n#farmer🌴 #SocialWorker 🫂#ProudIndian 🇮🇳#Familyman👨\u200d👩\u200d👦\u200d👦 #AyurvedaRepresentative🌿 #EcoGuradian #commonman😊🙏',
#     'url': 'https://t.co/LHigKpJoFY',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/LHigKpJoFY',
#         'expanded_url': 'https://instagram.com/iam_abdulsalim?igshid=YmMyMTA2M2Y=',
#         'display_url': 'instagram.com/iam_abdulsalim…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 40,
#     'friends_count': 398,
#     'listed_count': 0,
#     'created_at': 'Sat Jul 17 20:16:31 +0000 2021',
#     'favourites_count': 2780,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1627,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1570108338704379905/lX2Hr2XK_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1570108338704379905/lX2Hr2XK_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1416491989340762112/1659467217',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Sep 15 08:34:58 +0000 2022',
#    'id': 1570330319664087041,
#    'id_str': '1570330319664087041',
#    'text': '【#au 新機種予約】\n\n★予約受付中★\n9/16発売\n#iPhone14 \n#iPhone14ProMax \n#iPhone14Pro \n\n★下記URL又はQRから予約頂けます★\nhttps://t.co/rkyNVDPIjT… https://t.co/wvtvwxAnZX',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'au', 'indices': [1, 4]},
#      {'text': 'iPhone14', 'indices': [28, 37]},
#      {'text': 'iPhone14ProMax', 'indices': [39, 54]},
#      {'text': 'iPhone14Pro', 'indices': [56, 68]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/rkyNVDPIjT',
#       'expanded_url': 'https://onl.sc/48ksNXf',
#       'display_url': 'onl.sc/48ksNXf',
#       'indices': [91, 114]},
#      {'url': 'https://t.co/wvtvwxAnZX',
#       'expanded_url': 'https://twitter.com/i/web/status/1570330319664087041',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 866937388995457024,
#     'id_str': '866937388995457024',
#     'name': 'UQスポットららぽーと湘南平塚',
#     'screen_name': 'UQhiratsuka',
#     'location': '平塚',
#     'description': 'UQmobile専門店です！auのお取り扱いもございますので機種変更が並ばずにできますよ♪ 新規契約（MNP可）、料金相談随時受け付けております（＾ｖ＾） 営業時間10:00〜20:00 お得情報毎日配信致します！！ お電話はこちら☞ 0463-73-6141',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 715,
#     'friends_count': 623,
#     'listed_count': 10,
#     'created_at': 'Tue May 23 08:42:35 +0000 2017',
#     'favourites_count': 7,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 7,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1068100624909103105/A9-horda_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1068100624909103105/A9-horda_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/866937388995457024/1543489992',
#     'profile_link_color': '7FDBB6',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'ja'}],
#  'search_metadata': {'completed_in': 0.069,
#   'max_id': 1570330997606219776,
#   'max_id_str': '1570330997606219776',
#   'next_results': '?max_id=1570330319664087040&q=%23iPhone14Pro&include_entities=1',
#   'query': '%23iPhone14Pro',
#   'refresh_url': '?since_id=1570330997606219776&q=%23iPhone14Pro&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %% [markdown]
# ### Loading credentials and Tweepy authentication

# %%
# read configs

config = configparser.ConfigParser()
config.read('../../../config_files/config.ini')

api_key = config['twitter']['api_key']
api_key_secret = config['twitter']['api_key_secret']

access_token = config['twitter']['access_token']
access_token_secret = config['twitter']['access_token_secret']

# %%
# authentication

auth = tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %% [markdown]
# ### Data gathering from Twitter API

# %% [markdown]
# #### Option 1

# %%
# search by user

# user = 'veritasium'
# limit=300
# tweets = tweepy.Cursor(api.user_timeline, screen_name=user, count=200, tweet_mode='extended').items(limit)

# search by keyword or hashtag (works too for @user)
keywords = "#iPhone14Pro -filter:retweets"
limit = 1000
tweets = tweepy.Cursor(
    api.search_tweets, q=keywords, count=100, lang="en", tweet_mode="extended").items(limit)

# create DataFrame
columns = [
    "User",
    "Tweet_time",
    "Tweet",
    "Hashtag",
    "Retweet",
    "Favorite",
    "Join_time",
    "Follower",
    "Friend",
]

data = []

for tweet in tweets:
    data.append(
        [
            tweet.user.screen_name,
            tweet.created_at,
            tweet.full_text,
            tweet.entities["hashtags"],
            tweet.retweet_count,
            tweet.favorite_count,
            tweet.user.created_at,
            tweet.user.followers_count,
            tweet.user.friends_count,
        ]
    )

df = pd.DataFrame(data, columns=columns)

df.head()
# Out:
#             User                Tweet_time  \
# 0   qiandutech11 2022-09-15 07:26:42+00:00
# 1       torro_uk 2022-09-15 07:26:40+00:00
# 2  iShujaAhmedCh 2022-09-15 07:20:40+00:00
# 3       joanikin 2022-09-15 07:17:29+00:00
# 4      leobarnes 2022-09-15 07:16:08+00:00
#
#                                                Tweet  \
# 0  Are you looking for the new design phone cases...
# 1  Expecting an iPhone 14 delivery tomorrow? Don’...
# 2  The #iPhone14Pro and #iPhone14ProMax are avail...
# 3  Review: “This year’s iPhones (14) defy inflati...
# 4  The #GoProHERO11 was announced yesterday and w...
#
#                                              Hashtag  Retweet  Favorite  \
# 0  [{'text': 'iphone14', 'indices': [68, 77]}, {'...        0         0
# 1  [{'text': 'iphone14', 'indices': [163, 172]}, ...        0         0
# 2  [{'text': 'iPhone14Pro', 'indices': [4, 16]}, ...        0         0
# 3  [{'text': 'iPhone14', 'indices': [181, 190]}, ...        0         0
# 4  [{'text': 'GoProHERO11', 'indices': [4, 16]}, ...        0         0
#
#                   Join_time  Follower  Friend
# 0 2021-10-30 01:00:46+00:00         3      26
# 1 2013-03-18 19:56:37+00:00      4886     993
# 2 2009-08-02 20:52:11+00:00       743     715
# 3 2007-04-22 04:17:07+00:00      6811    2099
# 4 2015-01-04 19:21:35+00:00       663     860

# %% [markdown]
# #### Option 2

# %%
# gathering data from API

keywords = '#iPhone14Pro'
limit = 1000

tweets = tweepy.Cursor(api.search_tweets, q=keywords, lang='en', count=100,
                       tweet_mode='extended').items(limit)

# creating DataFrame

columns = ['User', 'DateTime', 'Tweet']
data = []

for tweet in tweets:
    data.append([tweet.user.screen_name, tweet.created_at, tweet.full_text])
    
df = pd.DataFrame(data, columns=columns)

df.head()
# Out:
#             User                  DateTime  \
# 0    mMarkGreece 2022-09-15 08:02:21+00:00
# 1     Owenjesse8 2022-09-15 08:02:20+00:00
# 2  nctdreamology 2022-09-15 08:01:51+00:00
# 3    Olaniel_art 2022-09-15 08:01:16+00:00
# 4     phone12s_i 2022-09-15 08:00:51+00:00
#
#                                                Tweet
# 0  @saucyrose1 Not even #itel may be. #iPhone14Pr...
# 1  RT @toba_chengi: Who knows the Twitter handle ...
# 2  RT @Chaerryyyyyyyyy: Rekomendasi ootd ala Kore...
# 3  RT @Mimi_Nation22: I love how far my mind can ...
# 4  RT @techboilers: iPhone 14 Pro Max has scored ...

# %%
#df.to_csv('../data/raw/iPhone14Prox10k_RAW_2.csv)

# %%
df14pro = pd.read_csv('../data/raw/iPhone14Prox10k_RAW.csv')
df14pro.head()
# Out:
#    Unnamed: 0             User                   DateTime  \
# 0           0         1202tung  2022-09-14 14:48:27+00:00
# 1           1  Rushike74038427  2022-09-14 14:48:05+00:00
# 2           2          papsobu  2022-09-14 14:47:40+00:00
# 3           3    _kayrozenlang  2022-09-14 14:47:27+00:00
# 4           4     SarenDebnath  2022-09-14 14:46:41+00:00
#
#                                                Tweet
# 0  RT @insanetweet: iPhone 8 while upgrading to i...
# 1  I want this case @Mrwhosetheboss \n#iphone14pr...
# 2  RT @insanetweet: iPhone 8 while upgrading to i...
# 3  RT @btslabs_global: 🏆Win iPhone14 Pro\n\nWith ...
# 4  RT @btslabs_global: 🏆Win iPhone14 Pro\n\nWith ...

# %%
df14pro['User'].value_counts()
# Out:
# thebbmafrica       63
# ChronicallyTG      41
# FaizanA17120449    40
# XXFemale1          39
# sgmobmart          34
#                    ..
# p_929303            1
# bonxcviii           1
# twtfnov             1
# axososad            1
# Getpaidrealquic     1
# Name: User, Length: 8703, dtype: int64

# %%
df14pro['Tweet'][0]
# Out:
# 'RT @insanetweet: iPhone 8 while upgrading to iOS 16\n\n#iOS16 #iPhone14 #iPhone14Pro \n https://t.co/IOpAaBnHus'

# %%
# removing punctuations and lowercase normalization
import string
text = df14pro['Tweet'][0]
text_clean1 = ''.join([i.lower() for i in text if i not in string.punctuation])
text_clean1
# Out:
# 'rt insanetweet iphone 8 while upgrading to ios 16\n\nios16 iphone14 iphone14pro \n httpstcoiopaabnhus'

# %%
# removing \n
import re
text_clean2 = re.sub('\n', ' ' , text_clean1)
text_clean2
# Out:
# 'rt insanetweet iphone 8 while upgrading to ios 16  ios16 iphone14 iphone14pro   httpstcoiopaabnhus'

# %%
# removing url
text_clean3 = result = re.sub(r'http\S+', '', text_clean2)
text_clean3
# Out:
# 'rt insanetweet iphone 8 while upgrading to ios 16  ios16 iphone14 iphone14pro   '

# %%
# importing stopwords
import nltk
from nltk.corpus import stopwords
cachedStopWords = stopwords.words('english')
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# removing stopwords
text = text_clean3
text = ' '.join([word for word in text.split() if word not in stopwords.words('english')])
print(text)
# Out:
# rt insanetweet iphone 8 upgrading ios 16 ios16 iphone14 iphone14pro
